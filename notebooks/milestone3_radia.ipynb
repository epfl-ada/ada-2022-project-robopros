# %% [markdown]
# # From Hollywood to Bollywood, an analysis of movie industries across time.
#
# ---

# %%
# Add local python scripts to path
import sys
sys.path.append('../src')
import load
import clean
import aggregate
import plot
import features

# %%
# Imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Linked to data collection
import json
import imdb
from bs4 import BeautifulSoup
import requests
import re
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 # Linked to data collection
#       2 import json
# ----> 3 import imdb
#       4 from bs4 import BeautifulSoup
#       5 import requests
#
# ModuleNotFoundError: No module named 'imdb'

# %%
#load the statistical libraries
from statsmodels.stats import diagnostic
from scipy import stats

# %%
# For the NLP 
import sklearn
import sklearn.model_selection
from sklearn.manifold import TSNE
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics.pairwise import cosine_similarity
from scipy import sparse
from fast_pagerank import pagerank
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [5], in <cell line: 11>()
#       9 from sklearn.metrics.pairwise import cosine_similarity
#      10 from scipy import sparse
# ---> 11 from fast_pagerank import pagerank
#
# ModuleNotFoundError: No module named 'fast_pagerank'

# %% [markdown]
# ## 1. Loading the datasets

# %% [markdown]
# Our analysis will look at differences between film industries from two perspectives, namely the movie themselves and the actors that play in them.
# Regarding movies, we will use the `movie.metadata.tsv` dataset for metadata, and `plot_summaries.txt` for the summaries.
# Regarding actors we will use the `character.metadata.tsv` dataset.
#
# Our loading functions allows us to do just that:

# %%
movies_raw = load.movie_metadata()
summaries_raw = load.plot_summaries()
characters_raw = load.character_metadata()

# %% [markdown]
# **Note:** the original movies metadata file uses a dictionary in format `{freebase_id:value}` for the columns `Movie_Countries`, `Movie_Genres`, and `Movie_Languages`. Our loading function parses these values and creates a unique row for each of them, such that each column holds a single value:

# %%
movies_raw[['Movie_Name', 'Movie_Countries', 'Movie_Languages', 'Movie_Genres']].head(3)
# Out:
#        Movie_Name           Movie_Countries   Movie_Languages     Movie_Genres
# 0  Ghosts of Mars  United States of America  English Language         Thriller
# 0  Ghosts of Mars  United States of America  English Language  Science Fiction
# 0  Ghosts of Mars  United States of America  English Language           Horror

# %% [markdown]
# We take a look at the number of raw datapoints in our dataset before cleaning:

# %%
ncountries_raw = aggregate.ncountries(movies_raw)
nmovies_raw = aggregate.nmovies(movies_raw)
nsummaries_raw = aggregate.nmovies(summaries_raw)
nactors_raw = aggregate.nactors(characters_raw)
print(f'- Number of countries:  {ncountries_raw:,}')
print(f'- Number of movies:     {nmovies_raw:,}')
print(f'- Number of summaries:  {nsummaries_raw:,}')
print(f'- Number of actors:     {nactors_raw:,}')
# Out:
# WARNING: DataFrame contains countries that are undefined
# WARNING: DataFrame contains actor IDs that are undefined
# - Number of countries:  147
# - Number of movies:     81,741
# - Number of summaries:  42,303
# - Number of actors:     135,760

# %% [markdown]
# Before we start extracting the features we're interested in, we have to do an initial cleaning of the data:
#
# 1. Our movie metadata contains movies from 147 countries (and some undefined), we are only interested in a few of them (for this analysis to be feasible).
# 2. Some characters have undefined actors, and should be dropped from analysis.
# 3. The character metadata and summaries data should be aligned with the country and date columns from the corresponding movie entries.
# 4. We have to choose time periods that has enough samples of each of the chosen countries.
#
# Let's start cleaning!

# %% [markdown]
# ## 2. Initial cleaning of the data

# %% [markdown]
# ### 2.1 Filtering countries of interest

# %% [markdown]
# To make comparisons between movies of different countries we assume that each movie comes from  a single country.
# This is not always the case, we therefore drop all movies that come from multiple countries.

# %%
movies_unique = clean.filter_unique_countries(movies_raw)
nmovies_unique = aggregate.nmovies(movies_unique)
print(f'Dropped {nmovies_raw - nmovies_unique:,} movies coming from multiple countries, {nmovies_unique:,} movies remaining.')
# Out:
# Dropped 17,372 movies coming from multiple countries, 64,369 movies remaining.

# %% [markdown]
# We are only interested in the largest movie industries of the world according to [1].
# To have meaningful comparisons we want to use enough movie samples from each of the country (at least 1000).

# %%
aggregate.top_countries_nmovies(movies_unique)
# Out:
#                           Wikipedia_Movie_ID
# Movie_Countries
# United States of America               30300
# India                                   8240
# United Kingdom                          5343
# Japan                                   2242
# France                                  1853
# Italy                                   1730
# Canada                                  1342
# Argentina                               1266
# Hong Kong                                850
# South Korea                              788

# %% [markdown]
# As we see above, we don't have enough movies for all large industries such as China and South Korea, this study will therefore only focus on US, India, UK, Japan, and France.

# %%
countries_of_interest = ['United States of America', 'India', 'United Kingdom', 'Japan', 'France']
movies_filtered = clean.keep_countries(movies_unique, countries_of_interest)
nmovies_filtered = aggregate.nmovies(movies_filtered)
print(f'Dropped {nmovies_unique - nmovies_filtered:,} movies, {nmovies_filtered:,} movies remaining.')
# Out:
# Dropped 16,391 movies, 47,978 movies remaining.

# %% [markdown]
# Now we only keep the characters that come from these countries and add the country as a new column.

# %%
characters_filtered = clean.align_movie_countries(characters_raw, movies_filtered)
nactors_filtered = aggregate.nactors(characters_filtered)
print(f'Dropped {nactors_raw - nactors_filtered} actors, {nactors_filtered} actors remaining.')
# Out:
# WARNING: DataFrame contains actor IDs that are undefined
# Dropped 53864 actors, 81896 actors remaining.

# %% [markdown]
# As we can see the country of the movie of each character is now added as an extra column.

# %%
characters_filtered[['Character_Name', 'Actor_Name', 'Movie_Countries']].head(3)
# Out:
#                Character_Name          Actor_Name           Movie_Countries
# 0                    Akooshay      Wanda De Jesus  United States of America
# 1  Lieutenant Melanie Ballard  Natasha Henstridge  United States of America
# 2         Desolation Williams            Ice Cube  United States of America

# %% [markdown]
# We do the same for the plot summaries:

# %%
summaries_filtered = clean.align_movie_countries(summaries_raw, movies_filtered)
nsummaries_filtered = aggregate.nmovies(summaries_filtered)
print(f'Dropped {nsummaries_raw - nsummaries_filtered} summaries, {nsummaries_filtered} summaries remaining.')
summaries_filtered[['Wikipedia_Movie_ID', 'Movie_Countries', 'Summary']].head(3)
# Out:
# Dropped 15613 summaries, 26690 summaries remaining.
#    Wikipedia_Movie_ID           Movie_Countries  \
# 0              975900  United States of America
# 1             9363483            United Kingdom
# 2             6631279  United States of America
#
#                                              Summary
# 0  Set in the second half of the 22nd century, th...
# 1  A series of murders of rich young women throug...
# 2  Adam, a San Francisco-based artist who works a...

# %% [markdown]
# As seen earlier, some characters have no actor data, and we therefore drop them.

# %%
characters_filtered = clean.drop_undefined_actors(characters_filtered)

# %% [markdown]
# Our cleaning is done, we see that while keeping 3% of the countries we keep around 60% of our original dataset.

# %%
movies = movies_filtered.reset_index().copy()
summaries = summaries_filtered.reset_index().copy()
characters = characters_filtered.reset_index().copy()

ncountries = aggregate.ncountries(movies)
nmovies = aggregate.nmovies(movies)
nsummaries = aggregate.nmovies(summaries)
nactors = aggregate.nactors(characters)
print('Finished filtering countries of interest:')
print(f'- Number of countries:  {ncountries:,} ({ncountries / ncountries_raw:.1%})')
print(f'- Number of movies:     {nmovies:,} ({nmovies / nmovies_raw:.1%})')
print(f'- Number of summaries:  {nsummaries:,} ({nsummaries / nsummaries_raw:.1%})')
print(f'- Number of actors:     {nactors:,} ({nactors / nactors_raw:.1%})')
# Out:
# Finished filtering countries of interest:
# - Number of countries:  5 (3.4%)
# - Number of movies:     47,978 (58.7%)
# - Number of summaries:  26,690 (63.1%)
# - Number of actors:     81,896 (60.3%)

# %% [markdown]
# ### 2.2 Filtering periods

# %% [markdown]
# We convert our columns corresponding to dates from string to datetime for easier manipulation and drop unspecified dates.

# %%
characters_parsed = clean.parse_dates(characters, 'Movie_Release_Date')
movies_parsed = clean.parse_dates(movies, 'Movie_Release_Date')

nactors_parsed = aggregate.nactors(characters_parsed)
nmovies_parsed = aggregate.nmovies(movies_parsed)

print(f'Dropped {nactors - nactors_parsed:,} actors, {nactors_parsed:,} actors remaining.')
print(f'Dropped {nmovies - nmovies_parsed:,} movies, {nmovies_parsed:,} movies remaining.')
# Out:
# Dropped 261 actors, 81,635 actors remaining.
# Dropped 2,477 movies, 45,501 movies remaining.

# %% [markdown]
# As a sanity check we make sure that the movie release dates are the same in the movies and characters tables.

# %%
ndifferences = clean.date_differences(movies_parsed, characters_parsed)
print(f'There are {ndifferences} differences between the movie and character dates.')
# Out:
# There are 0 differences between the movie and character dates.

# %% [markdown]
# We need a good representation of movies of each country over time.
# We visualize the number of movies over time and the fraction from each country to select a representative time interval.

# %%
plot.movie_distribution_over_time(movies_parsed)

# %% [markdown]
# Based on this visualization we select movies from 1950 to 2013 for our analysis, and see that movies from each country are sufficiently represented.

# %%
movies = clean.keep_dates(movies_parsed, 1950, 2013)
characters = clean.keep_dates(characters_parsed, 1950, 2013)
plot.movie_distribution_over_time(movies)

# %% [markdown]
# Add year and decade columns for convenient grouping.

# %%
clean.add_year_and_decade(movies)
clean.add_year_and_decade(characters)
summaries = clean.align_year_and_decade(summaries, characters)
movies[['Movie_Name', 'year', 'decade']].head(5)
# Out:
#        Movie_Name  year  decade
# 0  Ghosts of Mars  2001    2000
# 1  Ghosts of Mars  2001    2000
# 2  Ghosts of Mars  2001    2000
# 3  Ghosts of Mars  2001    2000
# 4  Ghosts of Mars  2001    2000

# %% [markdown]
# This leaves us with 40% of the original movies and 55% of the original actors.

# %%
ncountries = aggregate.ncountries(movies)
nmovies = aggregate.nmovies(movies)
nsummaries = aggregate.nmovies(summaries)
nactors = aggregate.nactors(characters)
print('Finished filtering dates:')
print(f'- Number of countries:  {ncountries:,} ({ncountries / ncountries_raw:.1%})')
print(f'- Number of movies:     {nmovies:,} ({nmovies / nmovies_raw:.1%})')
print(f'- Number of summaries:  {nsummaries:,} ({nsummaries / nsummaries_raw:.1%})')
print(f'- Number of actors:     {nactors:,} ({nactors / nactors_raw:.1%})')
# Out:
# Finished filtering dates:
# - Number of countries:  5 (3.4%)
# - Number of movies:     34,008 (41.6%)
# - Number of summaries:  20,108 (47.5%)
# - Number of actors:     74,133 (54.6%)

# %% [markdown]
# ## 3. Initial analysis
#
# We take a first look at the different features of our dataset and look for potential issues in the data.

# %% [markdown]
# ### 3.1 Movie attributes

# %% [markdown]
# #### 3.1.1 Duration of a movie
#
# Are movies from some countries shorter/longer than others?
# To answer this question we take a look at the movie runtimes from our movie dataset, which are expressed in minutes.
#
# Some movie runtimes are missing, these movies are dropped from analysis.

# %%
runtimes = features.runtimes(movies)
runtimes.head(5)
# Out:
# 6,043 (17.8%) movies without runtime. Keeping 27,965 (82.2%) movies.
#     Wikipedia_Movie_ID                                         Movie_Name  \
# 0               975900                                     Ghosts of Mars
# 7              3196793  Getting Away with Murder: The JonBenét Ramsey ...
# 11             9363483                                   White Of The Eye
# 27             2345652                                   City of the Dead
# 31            24229100           Lady Snowblood 2: Love Song of Vengeance
#
#     Movie_Runtime           Movie_Countries  decade
# 0            98.0  United States of America    2000
# 7            95.0  United States of America    2000
# 11          110.0            United Kingdom    1980
# 27           76.0            United Kingdom    1960
# 31           89.0                     Japan    1970

# %% [markdown]
# Looking at the descriptive statistics of movie runtimes, we see that all runtimes are positive as expected, but in a range from 1 to 1,000,000 minutes.
# We verify whether these are the actual runtime of the movies and filter erroneous data out.

# %%
runtimes.Movie_Runtime.describe()
# Out:
# count    2.796500e+04
# mean     1.380803e+02
# std      6.453918e+03
# min      1.000000e+00
# 25%      8.600000e+01
# 50%      9.500000e+01
# 75%      1.100000e+02
# max      1.079281e+06
# Name: Movie_Runtime, dtype: float64

# %% [markdown]
# We verified online whether some of the movies with "short runtime" (~1 min) was due to some error.
# It seemed that most of these movies were indeed short films.
# Therefore, for the analysis, we decided to keep these movies with "short runtime".

# %%
runtimes.sort_values(by='Movie_Runtime', ascending=True).head()
# Out:
#         Wikipedia_Movie_ID                            Movie_Name  \
# 146436               74877             Let's All Go to the Lobby
# 3851               8692428               Mickey Mouse in Vietnam
# 20964             34313572              A Computer Animated Hand
# 179432            24193081  The Astounding Talent of Mr. Grenade
# 171566             5565476                          Look at Life
#
#         Movie_Runtime           Movie_Countries  decade
# 146436            1.0  United States of America    1950
# 3851              1.0  United States of America    1960
# 20964             1.0  United States of America    1970
# 179432            1.0  United States of America    2000
# 171566            1.0  United States of America    1960

# %% [markdown]
# We also verified some of the "super long" movies online.
# The runtime of most of these movies were also legitimate.
# However, for one movie (Zero Tolerance (Wikipedia_Movie_ID 10815585)), the runtime was exceedingly long.
# The runtime for Zero Tolerance as recorded in the dataset is 1079281 mins.
# However, according to Guinness world record (https://www.guinnessworldrecords.com/), the longest movies ever recorded is "The Cure of Insomnia".
# There were only two movies "Zero Tolerance" and "Cinematon" longer than "The cure of Insomnia".
# "Cinematon", according to Wikipedia was indeed longer than "The cure for Insomnia".
# But we couldn't find any reliable source to justify the runtime of "Zero Tolerance".
# Therefore, we decided to omit the data of "Zero Tolerance" for our analysis.

# %%
runtimes.sort_values(by='Movie_Runtime', ascending=False).head()
# Out:
#         Wikipedia_Movie_ID                                       Movie_Name  \
# 28342             10815585                                   Zero Tolerance
# 158505            25345684                                        Cinématon
# 103527              884435                            The Cure for Insomnia
# 60352             36136594                             Kai Koduttha Dheivam
# 151902              884492  The Longest Most Meaningless Movie in the World
#
#         Movie_Runtime           Movie_Countries  decade
# 28342      1079281.00  United States of America    1990
# 158505        9360.00                    France    2010
# 103527        5220.00  United States of America    1980
# 60352         4875.27                     India    1960
# 151902        2880.00            United Kingdom    1960

# %% [markdown]
# Furthermore, looking at the distribution of movies, we see that anything above 300 minutes is an outlier.

# %%
# Have to use log scale to properly see data
plot.runtime_distribution(runtimes, log=True)

# %% [markdown]
# Indeed, such durations are from experimental movies and are outliers, and will therefore be left out of the analysis to avoid skewing the data too much.
# We now have a much cleaner distribution of movie runtimes.

# %%
clean_runtimes = runtimes[runtimes.Movie_Runtime <= 300]
# Note that we do not need the log axis anymore!
plot.runtime_distribution(clean_runtimes, log=False)

# %% [markdown]
# ### Milestone 3

# %% [markdown]
# Checking if the runtime of the movies are normally distributed.

# %%
diagnostic.kstest_normal(clean_runtimes['Movie_Runtime'].values, dist = 'norm')
# Out:
# (0.12546114429458233, 0.0009999999999998899)

# %% [markdown]
# - p_value < 0.05 -> we can reject the null hypothesis that the data comes from a normal distribution!

# %% [markdown]
# Checking if the runtime of the movies are exponentially distributed.

# %%
diagnostic.kstest_normal(clean_runtimes['Movie_Runtime'].values, dist = 'exp')
# Out:
# (0.40352798771338666, 0.0009999999999998899)

# %% [markdown]
# - p < 0.05 -> not exponential either!

# %%
#checking if normal distribution for different countries. 
US_clean_runtimes = clean_runtimes.query("Movie_Countries == 'United States of America'") 
print(diagnostic.kstest_normal(US_clean_runtimes['Movie_Runtime'].values, dist = 'norm'))

UK_clean_runtimes = clean_runtimes.query("Movie_Countries == 'United Kingdom'") 
print(diagnostic.kstest_normal(UK_clean_runtimes['Movie_Runtime'].values, dist = 'norm'))

Japan_clean_runtimes = clean_runtimes.query("Movie_Countries == 'Japan'") 
print(diagnostic.kstest_normal(Japan_clean_runtimes['Movie_Runtime'].values, dist = 'norm'))

India_clean_runtimes = clean_runtimes.query("Movie_Countries == 'India'") 
print(diagnostic.kstest_normal(India_clean_runtimes['Movie_Runtime'].values, dist = 'norm'))

France_clean_runtimes = clean_runtimes.query("Movie_Countries == 'France'") 
print(diagnostic.kstest_normal(France_clean_runtimes['Movie_Runtime'].values, dist = 'norm'))
# Out:
# (0.15967832597448556, 0.0009999999999998899)
# (0.1501446612125823, 0.0009999999999998899)
# (0.06951679042810105, 0.0009999999999998899)
# (0.06898952166158098, 0.0009999999999998899)
# (0.18058764085885448, 0.0009999999999998899)

# %%
#checking if exponential distribution for different countries. 
US_clean_runtimes = clean_runtimes.query("Movie_Countries == 'United States of America'") 
print(diagnostic.kstest_normal(US_clean_runtimes['Movie_Runtime'].values, dist = 'exp'))

UK_clean_runtimes = clean_runtimes.query("Movie_Countries == 'United Kingdom'") 
print(diagnostic.kstest_normal(UK_clean_runtimes['Movie_Runtime'].values, dist = 'exp'))

Japan_clean_runtimes = clean_runtimes.query("Movie_Countries == 'Japan'") 
print(diagnostic.kstest_normal(Japan_clean_runtimes['Movie_Runtime'].values, dist = 'exp'))

India_clean_runtimes = clean_runtimes.query("Movie_Countries == 'India'") 
print(diagnostic.kstest_normal(India_clean_runtimes['Movie_Runtime'].values, dist = 'exp'))

France_clean_runtimes = clean_runtimes.query("Movie_Countries == 'France'") 
print(diagnostic.kstest_normal(France_clean_runtimes['Movie_Runtime'].values, dist = 'exp'))
# Out:
# (0.42187928628835436, 0.0009999999999998899)
# (0.39334765283352735, 0.0009999999999998899)
# (0.36868160776319914, 0.0009999999999998899)
# (0.4542558625842701, 0.0009999999999998899)
# (0.430141335983036, 0.0009999999999998899)

# %% [markdown]
# The movie runtimes are neither normally distributed or exponentially distributed.

# %% [markdown]
# #### Hypothesis Testing

# %% [markdown]
# Is movie runtime in India longer than other countries (US, UK, Japan, France)

# %%
print("Mean runtime of movies in different countries")
print (f"India mean runtime: {India_clean_runtimes['Movie_Runtime'].mean()}")
print (f"USA mean runtime: {US_clean_runtimes['Movie_Runtime'].mean()}")
print (f"UK mean runtime: {UK_clean_runtimes['Movie_Runtime'].mean()}")
print (f"Japan mean runtime: {Japan_clean_runtimes['Movie_Runtime'].mean()}")
print (f"France mean runtime: {France_clean_runtimes['Movie_Runtime'].mean()}") 


print("Median runtime of movies in different countries") 

print (f"India mean runtime: {India_clean_runtimes['Movie_Runtime'].median()}")
print (f"USA mean runtime: {US_clean_runtimes['Movie_Runtime'].median()}")
print (f"UK mean runtime: {UK_clean_runtimes['Movie_Runtime'].median()}")
print (f"Japan mean runtime: {Japan_clean_runtimes['Movie_Runtime'].median()}")
print (f"France mean runtime: {France_clean_runtimes['Movie_Runtime'].median()}")
# Out:
# Mean runtime of movies in different countries
# India mean runtime: 141.6343498330385
# USA mean runtime: 91.66172636141967
# UK mean runtime: 88.96650567868565
# Japan mean runtime: 94.63802455146367
# France mean runtime: 93.54446640316206
# Median runtime of movies in different countries
# India mean runtime: 144.0
# USA mean runtime: 93.0
# UK mean runtime: 91.0
# Japan mean runtime: 96.0
# France mean runtime: 96.0

# %% [markdown]
# We used t-test to judge if the runtimes of Indian movies were indeed longer than other countries. This is a two-sided test for the null hypothesis that the two independent samples have identical average (expected) values.

# %%
ttest_India_US = stats.ttest_ind(India_clean_runtimes['Movie_Runtime'], US_clean_runtimes['Movie_Runtime'])
ttest_India_UK = stats.ttest_ind(India_clean_runtimes['Movie_Runtime'], UK_clean_runtimes['Movie_Runtime'])
ttest_India_Japan = stats.ttest_ind(India_clean_runtimes['Movie_Runtime'], Japan_clean_runtimes['Movie_Runtime'])
ttest_India_France = stats.ttest_ind(India_clean_runtimes['Movie_Runtime'], France_clean_runtimes['Movie_Runtime'])

print(f"India & US: {ttest_India_US}")
print(f"India & UK: {ttest_India_UK}")
print(f"India & Japan: {ttest_India_Japan}")
print(f"India & France: {ttest_India_France}")
# Out:
# India & US: Ttest_indResult(statistic=97.52538622041683, pvalue=0.0)
# India & UK: Ttest_indResult(statistic=77.2303577038677, pvalue=0.0)
# India & Japan: Ttest_indResult(statistic=58.32274940074651, pvalue=0.0)
# India & France: Ttest_indResult(statistic=54.208771946734345, pvalue=0.0)

# %% [markdown]
# After cleaning our runtimes, we create an initial visualization of the data to compare them between countries over time.
# It seems that movies from all countries are relatively the same length, except for Indian movies which seem to be longer.
# Over time duration from other countries seem to slightly increase while Indian movies seem to decrease.
# Further analysis will use proper statistical tests to verify the significance of these observations.

# %%
plot.runtime_comparison(clean_runtimes)

# %%
sns.boxplot(x="Movie_Countries", y="Movie_Runtime", data= clean_runtimes, hue="Movie_Genres")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 sns.boxplot(x="Movie_Countries", y="Movie_Runtime", data= clean_runtimes, hue="Movie_Genres")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:2243, in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2231 @_deprecate_positional_args
#    2232 def boxplot(
#    2233     *,
#    (...)
#    2240     **kwargs
#    2241 ):
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
#    2245                           width, dodge, fliersize, linewidth)
#    2247     if ax is None:
#    2248         ax = plt.gca()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:406, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     402 def __init__(self, x, y, hue, data, order, hue_order,
#     403              orient, color, palette, saturation,
#     404              width, dodge, fliersize, linewidth):
# --> 406     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407     self.establish_colors(color, palette, saturation)
#     409     self.dodge = dodge
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:153, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151     if isinstance(var, str):
#     152         err = "Could not interpret input '{}'".format(var)
# --> 153         raise ValueError(err)
#     155 # Figure out the plotting orientation
#     156 orient = infer_orient(
#     157     x, y, orient, require_numeric=self.require_numeric
#     158 )
#
# ValueError: Could not interpret input 'Movie_Genres'

# %% [markdown]
# #### 3.1.2 Movie revenue

# %% [markdown]
# The revenue of majority of the movies are missing. It would have been interesting to get a realiable data source for the revenues. However, there would be various other cofounders making the analysis unreliable. One such example would be the inflation accross different countries overtime would be different which would impact the revenue of the movies.

# %%
missing_revenues = aggregate.nmovies(movies[movies.Revenue.isna()])
print(f"We have {missing_revenues/nmovies:.1%} movies with missing revenue")
# Out:
# We have 83.8% movies with missing revenue

# %% [markdown]
# Because of the missing revenue (especially for Indian and Japanese movies) the values are a little all over the place.

# %%
revenues = movies[['Wikipedia_Movie_ID', 'Revenue', 'Movie_Countries', 'decade']].drop_duplicates()
g = sns.lineplot(data=revenues, x='decade', y='Revenue', hue='Movie_Countries')
g.set_yscale('log')
plt.show()

# %% [markdown]
# #### 3.1.3 Budget
#
# Since we don't have any data on budget, we will not do any analysis regarding the budget of the movies.

# %% [markdown]
# #### 3.1.4 Movie genres

# %% [markdown]
# This will need some creativity as I'm not sure if the below visualization is the best.
# Perhaps comparing the fraction of a genre relative to other genres within a country (within each period) would be more appropriate.
# More experimenting is needed here!

# %%
genres = movies[['Movie_Countries', 'Movie_Genres', 'decade']]
genres = genres.groupby(['Movie_Genres']).filter(lambda x: len(x) >= 1000)
sns.histplot(genres, y='Movie_Genres', hue='Movie_Countries', multiple='stack')
# Out:
# <AxesSubplot: xlabel='Count', ylabel='Movie_Genres'>

# %%
# get top 10 genres for each country
top_genres = movies[['Movie_Countries', 'Movie_Genres', 'decade']]
top_genres = top_genres.groupby(['Movie_Countries', 'Movie_Genres']).size().reset_index(name='counts')
top_genres = top_genres.sort_values(['Movie_Countries', 'counts'], ascending=[True, False])

# %%
top_genres.groupby('Movie_Countries').head(10)
# Out:
#                Movie_Countries      Movie_Genres  counts
# 59                      France             Drama     953
# 172                     France      World cinema     597
# 33                      France            Comedy     378
# 137                     France      Romance Film     272
# 164                     France          Thriller     199
# 56                      France       Documentary     181
# 48                      France     Crime Fiction     172
# 139                     France    Romantic drama     165
# 146                     France        Short Film     121
# 35                      France       Comedy film      79
# 221                      India             Drama    4494
# 308                      India      World cinema    2258
# 278                      India      Romance Film    1996
# 191                      India         Bollywood    1567
# 174                      India            Action    1459
# 260                      India           Musical    1394
# 199                      India            Comedy    1051
# 280                      India    Romantic drama     835
# 302                      India          Thriller     817
# 212                      India     Crime Fiction     508
# 403                      Japan   Japanese Movies    1845
# 469                      Japan      World cinema     638
# 367                      Japan             Drama     615
# 319                      Japan         Animation     380
# 320                      Japan             Anime     360
# 309                      Japan            Action     351
# 441                      Japan   Science Fiction     346
# 399                      Japan            Horror     244
# 381                      Japan           Fantasy     234
# 312                      Japan  Action/Adventure     209
# 551             United Kingdom             Drama    1572
# 517             United Kingdom            Comedy     869
# 704             United Kingdom          Thriller     537
# 538             United Kingdom     Crime Fiction     487
# 665             United Kingdom      Romance Film     382
# 547             United Kingdom       Documentary     308
# 604             United Kingdom            Horror     306
# 473             United Kingdom            Action     282
# 478             United Kingdom         Adventure     282
# 675             United Kingdom        Short Film     249
# 820   United States of America             Drama    8643
# 783   United States of America            Comedy    6322
# 1013  United States of America          Thriller    3892
# 718   United States of America            Action    3318
# 894   United States of America             Indie    3165
# 965   United States of America      Romance Film    2929
# 805   United States of America     Crime Fiction    2565
# 887   United States of America            Horror    2429
# 721   United States of America  Action/Adventure    2416
# 816   United States of America       Documentary    2404

# %% [markdown]
# Top 10 genres of each country

# %%
# plot top 10 genres for each country
top_genres = top_genres.groupby('Movie_Countries').head(10)
sns.histplot(top_genres, y='Movie_Genres', hue='Movie_Countries', multiple='stack')
# Out:
# <AxesSubplot: xlabel='Count', ylabel='Movie_Genres'>

# %% [markdown]
# #### 3.1.5 NLP insights

# %%
# read plot summaries
summaries_df = pd.read_csv('../data/MovieSummaries/plot_summaries.txt', sep='\t', header=None, names=['Wikipedia_Movie_ID', 'Plot_Summary'])

# %%
summaries_df.head(5)
# Out:
#    Wikipedia_Movie_ID                                       Plot_Summary
# 0            23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1            31186339  The nation of Panem consists of a wealthy Capi...
# 2            20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3             2231378  The Lemon Drop Kid , a New York City swindler,...
# 4              595909  Seventh-day Adventist Church pastor Michael Ch...

# %%
# match wikipedia movie ids 
movies_sum = movies.merge(summaries_df, on='Wikipedia_Movie_ID', how='left')

# %%
movies_sum = movies_sum[["Movie_Name", "Movie_Countries", "Movie_Genres", "Movie_Runtime", "Revenue", "Plot_Summary"]].drop_duplicates()

# %%
movies_sum.dropna(subset=['Plot_Summary'], inplace=True)

# %%
len(movies_sum)
# Out:
# 81171

# %%
# group summaries by genre and minmum number of char
summaries_gp = movies_sum.groupby(['Movie_Genres'])

# %%
summaries_gp.describe()
# Out:
#                  Movie_Runtime                                                \
#                          count        mean           std   min    25%    50%
# Movie_Genres
# Absurdism                 59.0   94.067797     21.757174  30.0   86.0   91.0
# Acid western               4.0   90.750000      0.957427  90.0   90.0   90.5
# Action                  2954.0  473.248043  19855.815835   1.5   90.0  100.0
# Action Comedy             71.0   98.422535     18.761406   8.0   91.0   99.0
# Action Thrillers         249.0  104.220884     19.787057  57.0   91.0   99.0
# ...                        ...         ...           ...   ...    ...    ...
# Workplace Comedy          61.0  100.196721     14.281479  77.0   89.0   98.0
# World History              4.0  176.000000    245.514426  40.0   55.0   60.0
# World cinema            2147.0  131.103891     49.699273  23.0  105.0  134.0
# Z movie                    2.0  100.000000     35.355339  75.0   87.5  100.0
# Zombie Film              137.0   87.116788     13.482050  17.0   84.0   89.0
#
#                                     Revenue                              \
#                      75%        max   count          mean           std
# Movie_Genres
# Absurdism          96.50      224.0    37.0  7.522848e+07  1.106102e+08
# Acid western       91.25       92.0     0.0           NaN           NaN
# Action            117.00  1079281.0  1087.0  8.928732e+07  1.629585e+08
# Action Comedy     105.00      146.0    52.0  8.209634e+07  1.145668e+08
# Action Thrillers  114.00      204.0   106.0  1.034876e+08  1.431546e+08
# ...                  ...        ...     ...           ...           ...
# Workplace Comedy  107.00      144.0    33.0  6.846822e+07  9.527865e+07
# World History     181.00      544.0     0.0           NaN           NaN
# World cinema      151.00     1966.0    95.0  1.796960e+07  2.783484e+07
# Z movie           112.50      125.0     0.0           NaN           NaN
# Zombie Film        93.00      115.0    25.0  4.226876e+07  1.154155e+08
#
#                                                                     \
#                         min          25%         50%           75%
# Movie_Genres
# Absurdism          118192.0   7027290.00  36145695.0  9.925546e+07
# Acid western            NaN          NaN         NaN           NaN
# Action              13276.0   6008754.50  25819961.0  9.320364e+07
# Action Comedy     2500000.0  13447683.25  34597148.5  8.609358e+07
# Action Thrillers   199436.0  12609880.00  42307113.5  1.606968e+08
# ...                     ...          ...         ...           ...
# Workplace Comedy   139084.0   7138523.00  26983776.0  9.057419e+07
# World History           NaN          NaN         NaN           NaN
# World cinema        24625.0   2376301.00   6548779.0  2.697482e+07
# Z movie                 NaN          NaN         NaN           NaN
# Zombie Film         54207.0   5364858.00  14182492.0  3.003939e+07
#
#
#                            max
# Movie_Genres
# Absurdism         5.814643e+08
# Acid western               NaN
# Action            1.511758e+09
# Action Comedy     6.243867e+08
# Action Thrillers  8.908716e+08
# ...                        ...
# Workplace Comedy  3.741117e+08
# World History              NaN
# World cinema      2.026143e+08
# Z movie                    NaN
# Zombie Film       5.853490e+08
#
# [330 rows x 16 columns]

# %% [markdown]
# The all-MiniLM-L6 https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2] is a light model good to detect semantics

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# print genres
for genre in summaries_gp.groups.keys():
    print(genre)
# Out:
# Absurdism
# Acid western
# Action
# Action Comedy
# Action Thrillers
# Action/Adventure
# Addiction Drama
# Adult
# Adventure
# Adventure Comedy
# Airplanes and airports
# Albino bias
# Alien Film
# Alien invasion
# Americana
# Animal Picture
# Animals
# Animated Musical
# Animated cartoon
# Animation
# Anime
# Anthology
# Anti-war
# Anti-war film
# Apocalyptic and post-apocalyptic fiction
# Archaeology
# Archives and records
# Art film
# Auto racing
# Avant-garde
# B-Western
# B-movie
# Backstage Musical
# Baseball
# Beach Film
# Beach Party film
# Bengali Cinema
# Biker Film
# Biographical film
# Biography
# Biopic [feature]
# Black comedy
# Black-and-white
# Blaxploitation
# Bloopers & Candid Camera
# Bollywood
# Boxing
# Breakdance
# British Empire Film
# British New Wave
# Buddy cop
# Buddy film
# Business
# C-Movie
# Camp
# Caper story
# Cavalry Film
# Chase Movie
# Chick flick
# Childhood Drama
# Children's
# Children's Entertainment
# Children's Fantasy
# Children's Issues
# Children's/Family
# Christian film
# Christmas movie
# Cold War
# Combat Films
# Comedy
# Comedy Thriller
# Comedy Western
# Comedy film
# Comedy horror
# Comedy of Errors
# Comedy of manners
# Comedy-drama
# Coming of age
# Coming-of-age film
# Computer Animation
# Computers
# Concert film
# Costume Adventure
# Costume Horror
# Costume drama
# Courtroom Comedy
# Courtroom Drama
# Creature Film
# Crime
# Crime Comedy
# Crime Drama
# Crime Fiction
# Crime Thriller
# Cult
# Culture & Society
# Cyberpunk
# Dance
# Demonic child
# Detective
# Detective fiction
# Disaster
# Docudrama
# Documentary
# Dogme 95
# Domestic Comedy
# Doomsday film
# Drama
# Dystopia
# Ealing Comedies
# Education
# Educational
# Ensemble Film
# Environmental Science
# Epic
# Epic Western
# Erotic Drama
# Erotic thriller
# Erotica
# Escape Film
# Essay Film
# Existentialism
# Experimental film
# Exploitation
# Extreme Sports
# Fairy tale
# Family & Personal Relationships
# Family Drama
# Family Film
# Family-Oriented Adventure
# Fan film
# Fantasy
# Fantasy Adventure
# Fantasy Comedy
# Fantasy Drama
# Feature film
# Female buddy film
# Feminist Film
# Fictional film
# Film
# Film & Television History
# Film adaptation
# Film noir
# Film à clef
# Film-Opera
# Filmed Play
# Finance & Investing
# Foreign legion
# Future noir
# Gangster Film
# Gay
# Gay Interest
# Gay Themed
# Gay pornography
# Gender Issues
# Giallo
# Glamorized Spy Film
# Gothic Film
# Graphic & Applied Arts
# Gross out
# Gross-out film
# Gulf War
# Hagiography
# Hardcore pornography
# Haunted House Film
# Health & Fitness
# Heaven-Can-Wait Fantasies
# Heavenly Comedy
# Heist
# Hip hop movies
# Historical Epic
# Historical drama
# Historical fiction
# History
# Holiday Film
# Horror
# Horror Comedy
# Horse racing
# Humour
# Hybrid Western
# Illnesses & Disabilities
# Indian Western
# Indie
# Inspirational Drama
# Instrumental Music
# Interpersonal Relationships
# Inventions & Innovations
# Japanese Movies
# Journalism
# Jukebox musical
# Jungle Film
# Juvenile Delinquency Film
# Kafkaesque
# Kitchen sink realism
# LGBT
# Language & Literature
# Law & Crime
# Legal drama
# Libraries and librarians
# Live action
# Malayalam Cinema
# Marriage Drama
# Martial Arts Film
# Master Criminal Films
# Media Satire
# Media Studies
# Medical fiction
# Melodrama
# Mockumentary
# Mondo film
# Monster
# Monster movie
# Movies About Gladiators
# Mumblecore
# Music
# Musical
# Musical Drama
# Musical comedy
# Mystery
# Mythological Fantasy
# Natural disaster
# Natural horror films
# Nature
# Neo-noir
# New Hollywood
# News
# Northern
# Nuclear warfare
# Outlaw
# Outlaw biker film
# Parkour in popular culture
# Parody
# Period Horror
# Period piece
# Pinku eiga
# Plague
# Point of view shot
# Political cinema
# Political drama
# Political satire
# Political thriller
# Pornographic movie
# Pornography
# Prison
# Prison escape
# Prison film
# Propaganda film
# Psycho-biddy
# Psychological horror
# Psychological thriller
# Punk rock
# Reboot
# Religious Film
# Remake
# Revenge
# Revisionist Fairy Tale
# Revisionist Western
# Road movie
# Road-Horror
# Roadshow theatrical release
# Rockumentary
# Romance Film
# Romantic comedy
# Romantic drama
# Romantic fantasy
# Samurai cinema
# Satire
# School story
# Sci Fi Pictures original films
# Sci-Fi Adventure
# Sci-Fi Horror
# Sci-Fi Thriller
# Science Fiction
# Science fiction Western
# Screwball comedy
# Sex comedy
# Sexploitation
# Short Film
# Silent film
# Singing cowboy
# Slapstick
# Slasher
# Slice of life story
# Social issues
# Social problem film
# Softcore Porn
# Space opera
# Space western
# Spaghetti Western
# Splatter film
# Sponsored film
# Sports
# Spy
# Stand-up comedy
# Star vehicle
# Statutory rape
# Steampunk
# Stoner film
# Stop motion
# Superhero
# Superhero movie
# Supermarionation
# Supernatural
# Surrealism
# Suspense
# Swashbuckler films
# Sword and Sandal
# Sword and sorcery
# Sword and sorcery films
# Tamil cinema
# Teen
# Television movie
# Therimin music
# Thriller
# Time travel
# Tokusatsu
# Tollywood
# Tragedy
# Tragicomedy
# Travel
# Vampire movies
# War film
# Werewolf fiction
# Western
# Whodunit
# Women in prison films
# Workplace Comedy
# World History
# World cinema
# Z movie
# Zombie Film

# %%
# %%time  
# encode action movies and romance movies
# perform the embedding only for one genre
action_embeddings = model.encode(summaries_gp.get_group('Action').Plot_Summary.tolist())
romance_embeddings = model.encode(summaries_gp.get_group('Romance Film').Plot_Summary.tolist())
# Out:
# CPU times: total: 32.6 s
# Wall time: 15.2 s

# %%
# ploting tsne for action and romance movies
from sklearn.manifold import TSNE
random_state = 42
model_tsne = TSNE(perplexity=10, n_components=2, init='pca', n_iter=2500, random_state=random_state)

# %%
action_tsne = model_tsne.fit_transform(action_embeddings)
romance_tsne = model_tsne.fit_transform(romance_embeddings)
# Out:
# c:\Users\rayendhahri\anaconda3\envs\machine\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# c:\Users\rayendhahri\anaconda3\envs\machine\lib\site-packages\sklearn\manifold\_t_sne.py:996: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# c:\Users\rayendhahri\anaconda3\envs\machine\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# c:\Users\rayendhahri\anaconda3\envs\machine\lib\site-packages\sklearn\manifold\_t_sne.py:996: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %%
plt.scatter(action_tsne[:, 0], action_tsne[:, 1], c='r', label='Action')
plt.scatter(romance_tsne[:, 0], romance_tsne[:, 1], c='b', label='Romance', alpha=0.2)

# %% [markdown]
# We see an overlap between 2 genres plots on a symmantic level with some differences. A throughout analysis will be presented by P3

# %% [markdown]
# We would like as well to determine the most significant x events. this is done by analyzing and studying the similarity between an event in a plot (sentence) and all the other remaing events happening.

# %%
movie_samples = movies_sum.sample(3, random_state=3)

# %%
movie_samples.head(3)
# Out:
#                      Movie_Name           Movie_Countries  Movie_Genres  \
# 31096               Unbreakable  United States of America  Supernatural
# 19663               Pale Cocoon                     Japan    Short Film
# 63940  Talkin' Dirty After Dark  United States of America        Comedy
#
#        Movie_Runtime      Revenue  \
# 31096          107.0  248118121.0
# 19663           23.0          NaN
# 63940           89.0          NaN
#
#                                             Plot_Summary
# 31096  Elijah Price  is born with Type I osteogenesis...
# 19663  It has been many years since a group of humans...
# 63940  Stand up comedian Terry  is a local funny man ...

# %%
# tokinize the plot summaries as sentences # a standard split would have been sufficient for these samples
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
movie_samples['Plot_Summary_sent'] = movie_samples['Plot_Summary'].apply(lambda x: sent_tokenize(x))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rayendhahri\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
movie_samples.head(3)
# Out:
#                      Movie_Name           Movie_Countries  Movie_Genres  \
# 31096               Unbreakable  United States of America  Supernatural
# 19663               Pale Cocoon                     Japan    Short Film
# 63940  Talkin' Dirty After Dark  United States of America        Comedy
#
#        Movie_Runtime      Revenue  \
# 31096          107.0  248118121.0
# 19663           23.0          NaN
# 63940           89.0          NaN
#
#                                             Plot_Summary  \
# 31096  Elijah Price  is born with Type I osteogenesis...
# 19663  It has been many years since a group of humans...
# 63940  Stand up comedian Terry  is a local funny man ...
#
#                                        Plot_Summary_sent
# 31096  [Elijah Price  is born with Type I osteogenesi...
# 19663  [It has been many years since a group of human...
# 63940  [Stand up comedian Terry  is a local funny man...

# %%
model_kps = SentenceTransformer("nlpaueb/bert-base-uncased-echr") # The warning is expected
# Out:
# HBox(children=(IntProgress(value=0, description='Downloading', max=391, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Downloading', max=11265, style=ProgressStyle(description_widt…
# HBox(children=(IntProgress(value=0, description='Downloading', max=1000, style=ProgressStyle(description_width…
# HBox(children=(IntProgress(value=0, description='Downloading', max=440474526, style=ProgressStyle(description_…
# HBox(children=(IntProgress(value=0, description='Downloading', max=48, style=ProgressStyle(description_width='…
# HBox(children=(IntProgress(value=0, description='Downloading', max=231508, style=ProgressStyle(description_wid…
# No sentence-transformers model found with name C:\Users\rayendhahri/.cache\torch\sentence_transformers\nlpaueb_bert-base-uncased-echr. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at C:\Users\rayendhahri/.cache\torch\sentence_transformers\nlpaueb_bert-base-uncased-echr were not used when initializing BertModel: ['cls.predictions.decoder.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def gen_match_matrix(model, sents, min_match_score=0):
    """Generate a matrix of sentence matches for a list of sentences"""
    sents1 = [x for x in sents]
    sents1_embeddings = model.encode(sents1)
    sim_matrix = cosine_similarity(sents1_embeddings, sents1_embeddings)
    super_threshold_indices = sim_matrix < min_match_score
    sim_matrix[super_threshold_indices] = 0
    #print(sim_matrix)
    return sim_matrix

# %%
def filter_ranked_list(ranked_sents, model, min_match=0.8, N=3):
    """a ranked list of sentences is filtered by removing sentences that are too similar to other sentences in the list
    N is the number of sentences to return"""
    ranked_sents = [x[0] for x in ranked_sents]
    filtered_sents = []
    for i, s in enumerate(ranked_sents):
        if len(filtered_sents) >= N or len(filtered_sents) >= len(ranked_sents):
            break
        if len(filtered_sents) == 0:
            filtered_sents.append(s)
        else:
            matching_scores = gen_match_matrix(model, [s] + filtered_sents)
            max_sim = np.max(matching_scores[0][1:])
            # print(matching_scores)
            if max_sim < min_match:
                filtered_sents.append(s)
        
        # print(min_match)
    
    return filtered_sents

# %%
def apply_page_rank(sentences, p=0.85, min_match_score=0.5, min_len=5, max_len=35):
    """Apply page rank to a list of sentences
    min_match_score: minimum similarity score for two sentences to be considered similar
    min_len: minimum length of a sentence
    max_len: maximum length of a sentence
    returns a ranked list of sentences
    """
    cand_sents = [x for x in sentences if len(x.split()) < max_len and len(x.split()) > min_len]
    if len(cand_sents) == 0:
        #print('empty')
        return []
    # print(cands)
    # print(cands_qualities)
    cands_matching_mat = gen_match_matrix(model, cand_sents, min_match_score=min_match_score)
    pr = pagerank(cands_matching_mat, p=p)  # it looks like modifying the initial probability doesn't help
    # pr=pagerank(cands_matching_mat, p=p)
    ranked_candidates = list(zip(cand_sents, pr))
    return sorted(ranked_candidates, key=lambda x: -x[1])

# %%
# lets get 3 most influencial sentences for each movie
movie_samples["summary_kps"] = movie_samples["Plot_Summary_sent"].apply(lambda x: apply_page_rank(x, p=0.85, min_match_score=0.5, min_len=5, max_len=35))
movie_samples["summary_kps"] = movie_samples["summary_kps"].apply(lambda x: filter_ranked_list(x, model_kps, min_match=0.8, N=3))
# Out:
# c:\Users\rayendhahri\anaconda3\envs\machine\lib\site-packages\scipy\sparse\linalg\_dsolve\linsolve.py:168: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   warn('spsolve requires A be CSC or CSR matrix format',
# c:\Users\rayendhahri\anaconda3\envs\machine\lib\site-packages\scipy\sparse\linalg\_dsolve\linsolve.py:168: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   warn('spsolve requires A be CSC or CSR matrix format',
# c:\Users\rayendhahri\anaconda3\envs\machine\lib\site-packages\scipy\sparse\linalg\_dsolve\linsolve.py:168: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   warn('spsolve requires A be CSC or CSR matrix format',

# %%
# display the results full sentences
movie_samples[["Movie_Name", "summary_kps"]]
# Out:
#                      Movie_Name  \
# 31096               Unbreakable
# 19663               Pale Cocoon
# 63940  Talkin' Dirty After Dark
#
#                                              summary_kps
# 31096  [David tries to console his son by saying that...
# 19663  [It has been many years since a group of human...
# 63940  [He is struggling trying to make it at a local...

# %% [markdown]
# ### 3.2 Diversity across industries
#
# Possible metrics between countries:
# - Age
# - Gender ratio
# - Ethnicity (although not much data, not sure if we can complete w/ other datasources)
# - Actor height compared to national averages
#
# This task should be similar to H1, just comparing populations using the appropriate statistic metrics.
#
# Initial needed data wrangling:
# - Age should be in the right range
# - Gender ratio in an appropriate format for comparing
# - Check if there is enough ethnicity data and if not try to obtain them from outside data source
# - Obtain national heigh averages and compare them with appropriate methods

# %% [markdown]
# #### 3.2.1 Age

# %%
# assign to new variable
char_age = characters
characters.head()
# Out:
#    index  Wikipedia_Movie_ID           Movie_Countries Freebase_Movie_ID  \
# 0      0              975900  United States of America         /m/03vyhn
# 1      1              975900  United States of America         /m/03vyhn
# 2      2              975900  United States of America         /m/03vyhn
# 3      3              975900  United States of America         /m/03vyhn
# 4      4              975900  United States of America         /m/03vyhn
#
#   Movie_Release_Date              Character_Name   Actor_DOB Actor_Gender  \
# 0         2001-08-24                    Akooshay  1958-08-26            F
# 1         2001-08-24  Lieutenant Melanie Ballard  1974-08-15            F
# 2         2001-08-24         Desolation Williams  1969-06-15            M
# 3         2001-08-24          Sgt Jericho Butler  1967-09-12            M
# 4         2001-08-24             Bashira Kincaid  1977-09-25            F
#
#    Actor_Height Actor_Ethnicity          Actor_Name  \
# 0         1.620             NaN      Wanda De Jesus
# 1         1.780      /m/044038p  Natasha Henstridge
# 2         1.727         /m/0x67            Ice Cube
# 3         1.750             NaN       Jason Statham
# 4         1.650             NaN         Clea DuVall
#
#    Actor_Age_at_Movie_Release Freebase_Char_Actor_Map_ID Freebase_Char_ID  \
# 0                        42.0                 /m/0bgchxw       /m/0bgcj3x
# 1                        27.0                  /m/0jys3m       /m/0bgchn4
# 2                        32.0                  /m/0jys3g       /m/0bgchn_
# 3                        33.0                 /m/02vchl6       /m/0bgchnq
# 4                        23.0                 /m/02vbb3r       /m/0bgchp9
#
#   Freebase_Actor_ID  year  decade
# 0        /m/03wcfv7  2001    2000
# 1         /m/0346l4  2001    2000
# 2        /m/01vw26l  2001    2000
# 3         /m/034hyc  2001    2000
# 4         /m/01y9xg  2001    2000

# %%
char_age.describe()
# Out:
#                index  Wikipedia_Movie_ID   Actor_Height  \
# count  244681.000000        2.446810e+05  100825.000000
# mean   148160.714661        1.265739e+07       1.769042
# std     85665.407806        1.056337e+07       2.885711
# min         0.000000        3.217000e+03       0.813000
# 25%     73923.000000        3.076631e+06       1.680000
# 50%    148000.000000        9.652328e+06       1.750000
# 75%    222682.000000        2.168464e+07       1.830000
# max    296570.000000        3.750192e+07     510.000000
#
#        Actor_Age_at_Movie_Release           year         decade
# count               179121.000000  244681.000000  244681.000000
# mean                    38.487319    1990.977603    1986.419501
# std                     23.652003      17.486817      17.522796
# min                  -7896.000000    1950.000000    1950.000000
# 25%                     28.000000    1979.000000    1970.000000
# 50%                     37.000000    1996.000000    1990.000000
# 75%                     48.000000    2006.000000    2000.000000
# max                    103.000000    2013.000000    2010.000000

# %% [markdown]
# There are still some inconsistencies in age which have to be filtered out. Data with negative age and NaN value will be removed.

# %%
# data with errors
char_age[char_age.Actor_Age_at_Movie_Release < 0].head()
# Out:
#        index  Wikipedia_Movie_ID           Movie_Countries Freebase_Movie_ID  \
# 6928    6948            31163724  United States of America        /m/0gdk5td
# 8910    8933            21242801  United States of America        /m/05bzjwj
# 13154  13184            20019382  United States of America        /m/04y9xhm
# 21739  21795             5261848  United States of America         /m/0dbfw4
# 23138  23194            11143228                     India        /m/02r1gz2
#
#       Movie_Release_Date Character_Name   Actor_DOB Actor_Gender  \
# 6928          1956-01-01            NaN        1973            M
# 8910          1955-08-07            NaN  1973-08-01            M
# 13154         1977-09-28      El Raheem  2004-01-13            M
# 21739         1988-01-24            NaN  1992-10-19          NaN
# 23138         1976-01-01            NaN        1982            F
#
#        Actor_Height Actor_Ethnicity               Actor_Name  \
# 6928            NaN             NaN      Eric Chase Anderson
# 8910           1.79       /m/03ttfc          Eduardo Noriega
# 13154           NaN             NaN              Don Blakely
# 21739           NaN             NaN              Perry Allen
# 23138           NaN             NaN  Vijayalakshmi Agathiyan
#
#        Actor_Age_at_Movie_Release Freebase_Char_Actor_Map_ID Freebase_Char_ID  \
# 6928                        -17.0                 /m/0gdljss              NaN
# 8910                        -17.0                 /m/0cg2f0f              NaN
# 13154                       -26.0                 /m/0cgrzfq       /m/0cgrzft
# 21739                        -4.0                 /m/06mg50n              NaN
# 23138                        -6.0                 /m/0kn359c              NaN
#
#       Freebase_Actor_ID  year  decade
# 6928         /m/026xg0t  1956    1950
# 8910          /m/0bkkw0  1955    1950
# 13154        /m/0bhh1hn  1977    1970
# 21739        /m/06mg50r  1988    1980
# 23138        /m/04gltqm  1976    1970

# %% [markdown]
# This is the data without missing/wrong data about the actor's age:

# %%
# clean dataframe
clean.positive_age(char_age)
# Out:
#          index  Wikipedia_Movie_ID           Movie_Countries  \
# 0            0              975900  United States of America
# 1            1              975900  United States of America
# 2            2              975900  United States of America
# 3            3              975900  United States of America
# 4            4              975900  United States of America
# ...        ...                 ...                       ...
# 295974  296563              913762                     Japan
# 295976  296565              913762                     Japan
# 295977  296566              913762                     Japan
# 295978  296567              913762                     Japan
# 295981  296570              913762                     Japan
#
#        Freebase_Movie_ID Movie_Release_Date              Character_Name  \
# 0              /m/03vyhn         2001-08-24                    Akooshay
# 1              /m/03vyhn         2001-08-24  Lieutenant Melanie Ballard
# 2              /m/03vyhn         2001-08-24         Desolation Williams
# 3              /m/03vyhn         2001-08-24          Sgt Jericho Butler
# 4              /m/03vyhn         2001-08-24             Bashira Kincaid
# ...                  ...                ...                         ...
# 295974         /m/03pcrp         1992-05-21                   Lord Feff
# 295976         /m/03pcrp         1992-05-21           Additional Voices
# 295977         /m/03pcrp         1992-05-21          UN Spacy Commander
# 295978         /m/03pcrp         1992-05-21                 Silvie Gena
# 295981         /m/03pcrp         1992-05-21                      Hibiki
#
#          Actor_DOB Actor_Gender  Actor_Height Actor_Ethnicity  \
# 0       1958-08-26            F         1.620             NaN
# 1       1974-08-15            F         1.780      /m/044038p
# 2       1969-06-15            M         1.727         /m/0x67
# 3       1967-09-12            M         1.750             NaN
# 4       1977-09-25            F         1.650             NaN
# ...            ...          ...           ...             ...
# 295974  1960-04-28            M           NaN             NaN
# 295976        1954            M           NaN             NaN
# 295977        1954            M           NaN             NaN
# 295978        1958            F           NaN             NaN
# 295981  1965-04-12            M           NaN             NaN
#
#                 Actor_Name  Actor_Age_at_Movie_Release  \
# 0           Wanda De Jesus                        42.0
# 1       Natasha Henstridge                        27.0
# 2                 Ice Cube                        32.0
# 3            Jason Statham                        33.0
# 4              Clea DuVall                        23.0
# ...                    ...                         ...
# 295974         Steven Blum                        32.0
# 295976       Sonny Byrkett                        38.0
# 295977       Sonny Byrkett                        38.0
# 295978       Susan Byrkett                        34.0
# 295981       Jonathan Fahn                        27.0
#
#        Freebase_Char_Actor_Map_ID Freebase_Char_ID Freebase_Actor_ID  year  \
# 0                      /m/0bgchxw       /m/0bgcj3x        /m/03wcfv7  2001
# 1                       /m/0jys3m       /m/0bgchn4         /m/0346l4  2001
# 2                       /m/0jys3g       /m/0bgchn_        /m/01vw26l  2001
# 3                      /m/02vchl6       /m/0bgchnq         /m/034hyc  2001
# 4                      /m/02vbb3r       /m/0bgchp9         /m/01y9xg  2001
# ...                           ...              ...               ...   ...
# 295974                 /m/0kr408g       /m/0kr408l         /m/044_7j  1992
# 295976                 /m/0kr405f       /m/0kr405k         /m/0gn4bz  1992
# 295977                 /m/0kr407w       /m/0kr407_         /m/0gn4bz  1992
# 295978                 /m/0kr40b9       /m/0kr40bf         /m/0gn4nd  1992
# 295981                 /m/0kr405_       /m/0kr4090         /m/0bx7_j  1992
#
#         decade
# 0         2000
# 1         2000
# 2         2000
# 3         2000
# 4         2000
# ...        ...
# 295974    1990
# 295976    1990
# 295977    1990
# 295978    1990
# 295981    1990
#
# [178957 rows x 17 columns]

# %% [markdown]
# For some characters age is missing but can be calculated with DOB and Release Date of the movie. Even in the Actor_DOB column exist inconsistencies, as the supposed actor was born in 1498 and took part in a movie almost 300 years later:

# %%
# characters with dob (date of birth) and mrd (movie release date) but not age at movie release
dob_mrd_char = load.release_birth_date(char_age)
dob_mrd_char[pd.to_datetime(dob_mrd_char.Actor_DOB, format='%Y/%m/%d', errors='coerce').isnull()]
# Out:
#          index  Wikipedia_Movie_ID           Movie_Countries  \
# 2457      2464            21038272                     India
# 120931  121161            20072112  United States of America
#
#        Freebase_Movie_ID Movie_Release_Date Character_Name   Actor_DOB  \
# 2457          /m/05b268g         1979-01-01            NaN        1498
# 120931        /m/04n46f5         2008-01-01            NaN  1075-08-19
#
#        Actor_Gender  Actor_Height Actor_Ethnicity       Actor_Name  \
# 2457              F           NaN             NaN          Mirabai
# 120931            F           NaN             NaN  Holly Eglington
#
#         Actor_Age_at_Movie_Release Freebase_Char_Actor_Map_ID  \
# 2457                           NaN                 /m/05cnn3x
# 120931                         NaN                 /m/0gc7_rh
#
#        Freebase_Char_ID Freebase_Actor_ID  year  decade
# 2457                NaN         /m/03h165  1979    1970
# 120931              NaN        /m/0gc64t0  2008    2000

# %%
# drop these rows
char_age, removed_idx = clean.date_range(dob_mrd_char, char_age)
char_age
# Out:
#          index  Wikipedia_Movie_ID           Movie_Countries  \
# 0            0              975900  United States of America
# 1            1              975900  United States of America
# 2            2              975900  United States of America
# 3            3              975900  United States of America
# 4            4              975900  United States of America
# ...        ...                 ...                       ...
# 295977  296566              913762                     Japan
# 295978  296567              913762                     Japan
# 295979  296568              913762                     Japan
# 295980  296569              913762                     Japan
# 295981  296570              913762                     Japan
#
#        Freebase_Movie_ID Movie_Release_Date              Character_Name  \
# 0              /m/03vyhn         2001-08-24                    Akooshay
# 1              /m/03vyhn         2001-08-24  Lieutenant Melanie Ballard
# 2              /m/03vyhn         2001-08-24         Desolation Williams
# 3              /m/03vyhn         2001-08-24          Sgt Jericho Butler
# 4              /m/03vyhn         2001-08-24             Bashira Kincaid
# ...                  ...                ...                         ...
# 295977         /m/03pcrp         1992-05-21          UN Spacy Commander
# 295978         /m/03pcrp         1992-05-21                 Silvie Gena
# 295979         /m/03pcrp         1992-05-21                     Exegran
# 295980         /m/03pcrp         1992-05-21                      Elensh
# 295981         /m/03pcrp         1992-05-21                      Hibiki
#
#          Actor_DOB Actor_Gender  Actor_Height Actor_Ethnicity  \
# 0       1958-08-26            F         1.620             NaN
# 1       1974-08-15            F         1.780      /m/044038p
# 2       1969-06-15            M         1.727         /m/0x67
# 3       1967-09-12            M         1.750             NaN
# 4       1977-09-25            F         1.650             NaN
# ...            ...          ...           ...             ...
# 295977        1954            M           NaN             NaN
# 295978        1958            F           NaN             NaN
# 295979         NaN            M           NaN             NaN
# 295980     1970-05            F           NaN             NaN
# 295981  1965-04-12            M           NaN             NaN
#
#                 Actor_Name  Actor_Age_at_Movie_Release  \
# 0           Wanda De Jesus                        42.0
# 1       Natasha Henstridge                        27.0
# 2                 Ice Cube                        32.0
# 3            Jason Statham                        33.0
# 4              Clea DuVall                        23.0
# ...                    ...                         ...
# 295977       Sonny Byrkett                        38.0
# 295978       Susan Byrkett                        34.0
# 295979      Hal Cleaveland                         NaN
# 295980  Dorothy Elias-Fahn                         NaN
# 295981       Jonathan Fahn                        27.0
#
#        Freebase_Char_Actor_Map_ID Freebase_Char_ID Freebase_Actor_ID  year  \
# 0                      /m/0bgchxw       /m/0bgcj3x        /m/03wcfv7  2001
# 1                       /m/0jys3m       /m/0bgchn4         /m/0346l4  2001
# 2                       /m/0jys3g       /m/0bgchn_        /m/01vw26l  2001
# 3                      /m/02vchl6       /m/0bgchnq         /m/034hyc  2001
# 4                      /m/02vbb3r       /m/0bgchp9         /m/01y9xg  2001
# ...                           ...              ...               ...   ...
# 295977                 /m/0kr407w       /m/0kr407_         /m/0gn4bz  1992
# 295978                 /m/0kr40b9       /m/0kr40bf         /m/0gn4nd  1992
# 295979                 /m/0kr407c       /m/0kr406_        /m/0kr407h  1992
# 295980                 /m/0kr406c       /m/0kr406h         /m/0b_vcv  1992
# 295981                 /m/0kr405_       /m/0kr4090         /m/0bx7_j  1992
#
#         decade
# 0         2000
# 1         2000
# 2         2000
# 3         2000
# 4         2000
# ...        ...
# 295977    1990
# 295978    1990
# 295979    1990
# 295980    1990
# 295981    1990
#
# [244679 rows x 17 columns]

# %%
# convert into date format to extract year
dob_mrd_char = clean.parse_dates(dob_mrd_char, 'Actor_DOB')
dob_mrd_char = clean.parse_dates(dob_mrd_char, 'Movie_Release_Date')
dob_mrd_char
# Out:
#          index  Wikipedia_Movie_ID           Movie_Countries  \
# 85          85               77856  United States of America
# 87          87               77856  United States of America
# 91          91               77856  United States of America
# 280        280             5915856                     India
# 281        281             5915856                     India
# ...        ...                 ...                       ...
# 295532  296120            25431214                     India
# 295533  296121            25431214                     India
# 295534  296122            25431214                     India
# 295535  296123            25431214                     India
# 295980  296569              913762                     Japan
#
#        Freebase_Movie_ID Movie_Release_Date Character_Name  \
# 85              /m/0kcn7         1964-08-27  The Constable
# 87              /m/0kcn7         1964-08-27   Uncle Albert
# 91              /m/0kcn7         1964-08-27   Admiral Boom
# 280            /m/0fdc85         2003-10-01            NaN
# 281            /m/0fdc85         2003-10-01            NaN
# ...                  ...                ...            ...
# 295532        /m/09k5h57         2009-12-01        Mathews
# 295533        /m/09k5h57         2009-12-01   Adv. Sunitha
# 295534        /m/09k5h57         2009-12-01  Adv. Prabalan
# 295535        /m/09k5h57         2009-12-01            NaN
# 295980         /m/03pcrp         1992-05-21         Elensh
#
#                   Actor_DOB Actor_Gender  Actor_Height Actor_Ethnicity  \
# 85      1894-07-23 00:00:00            M           NaN             NaN
# 87      1886-11-09 00:00:00            M        1.8200             NaN
# 91      1887-08-05 00:00:00            M           NaN             NaN
# 280     1970-09-09 00:00:00            M           NaN             NaN
# 281     1965-12-10 00:00:00            M           NaN             NaN
# ...                     ...          ...           ...             ...
# 295532  1960-05-21 00:00:00            M        1.7200      /m/0dryh9k
# 295533  1989-05-05 00:00:00            F        1.7018       /m/074w_m
# 295534  1956-04-06 00:00:00            M           NaN       /m/046cwm
# 295535  1985-06-30 00:00:00            F           NaN             NaN
# 295980  1970-05-01 00:00:00            F           NaN             NaN
#
#                 Actor_Name  Actor_Age_at_Movie_Release  \
# 85         Arthur Treacher                         NaN
# 87                 Ed Wynn                         NaN
# 91           Reginald Owen                         NaN
# 280             Biju Menon                         NaN
# 281                Jayaram                         NaN
# ...                    ...                         ...
# 295532            Mohanlal                         NaN
# 295533         Lakshmi Rai                         NaN
# 295534         Sreenivasan                         NaN
# 295535       Priyanka Nair                         NaN
# 295980  Dorothy Elias-Fahn                         NaN
#
#        Freebase_Char_Actor_Map_ID Freebase_Char_ID Freebase_Actor_ID  year  \
# 85                     /m/0cg2t2_       /m/0h5njw9         /m/020csj  1964
# 87                     /m/05nn480       /m/05ysxy5         /m/01k67w  1964
# 91                     /m/0csl6kq       /m/0h5njw2         /m/0b47ns  1964
# 280                     /m/0j_1kz              NaN         /m/0g9d5d  2003
# 281                     /m/0j_1kn              NaN         /m/075p0r  2003
# ...                           ...              ...               ...   ...
# 295532                 /m/0gvzwgy       /m/0h1j8l9         /m/02fbpz  2009
# 295533                 /m/0gvz_3b       /m/0h34ydz        /m/02pnknk  2009
# 295534                 /m/0hh977l       /m/0hh977p         /m/05gc0h  2009
# 295535                 /m/0n9_2kr              NaN        /m/0czbskd  2009
# 295980                 /m/0kr406c       /m/0kr406h         /m/0b_vcv  1992
#
#         decade
# 85        1960
# 87        1960
# 91        1960
# 280       2000
# 281       2000
# ...        ...
# 295532    2000
# 295533    2000
# 295534    2000
# 295535    2000
# 295980    1990
#
# [10456 rows x 17 columns]

# %% [markdown]
# The age of the actors are based on the year of birth and year of movie release as the data does not provide a consistent format including day and month dates for all subjects.

# %%
# replace the actors' calculated ages and remove the wrong data
# replace NaN with calculated age in original dataframe
char_age = clean.calc_age(dob_mrd_char, char_age, removed_idx)
# Out:
# C:\Users\Tim\OneDrive\Studium M. Sc\EPFL\ADA\ada-2022-project-robopros\notebooks\../src\clean.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.Actor_Age_at_Movie_Release.loc[df1.index] = df1.Actor_Age_at_Movie_Release

# %%
# cleansed data
char_age = clean.positive_age(char_age)
char_age
# Out:
#          index  Wikipedia_Movie_ID           Movie_Countries  \
# 0            0              975900  United States of America
# 1            1              975900  United States of America
# 2            2              975900  United States of America
# 3            3              975900  United States of America
# 4            4              975900  United States of America
# ...        ...                 ...                       ...
# 295976  296565              913762                     Japan
# 295977  296566              913762                     Japan
# 295978  296567              913762                     Japan
# 295980  296569              913762                     Japan
# 295981  296570              913762                     Japan
#
#        Freebase_Movie_ID Movie_Release_Date              Character_Name  \
# 0              /m/03vyhn         2001-08-24                    Akooshay
# 1              /m/03vyhn         2001-08-24  Lieutenant Melanie Ballard
# 2              /m/03vyhn         2001-08-24         Desolation Williams
# 3              /m/03vyhn         2001-08-24          Sgt Jericho Butler
# 4              /m/03vyhn         2001-08-24             Bashira Kincaid
# ...                  ...                ...                         ...
# 295976         /m/03pcrp         1992-05-21           Additional Voices
# 295977         /m/03pcrp         1992-05-21          UN Spacy Commander
# 295978         /m/03pcrp         1992-05-21                 Silvie Gena
# 295980         /m/03pcrp         1992-05-21                      Elensh
# 295981         /m/03pcrp         1992-05-21                      Hibiki
#
#          Actor_DOB Actor_Gender  Actor_Height Actor_Ethnicity  \
# 0       1958-08-26            F         1.620             NaN
# 1       1974-08-15            F         1.780      /m/044038p
# 2       1969-06-15            M         1.727         /m/0x67
# 3       1967-09-12            M         1.750             NaN
# 4       1977-09-25            F         1.650             NaN
# ...            ...          ...           ...             ...
# 295976        1954            M           NaN             NaN
# 295977        1954            M           NaN             NaN
# 295978        1958            F           NaN             NaN
# 295980     1970-05            F           NaN             NaN
# 295981  1965-04-12            M           NaN             NaN
#
#                 Actor_Name  Actor_Age_at_Movie_Release  \
# 0           Wanda De Jesus                        42.0
# 1       Natasha Henstridge                        27.0
# 2                 Ice Cube                        32.0
# 3            Jason Statham                        33.0
# 4              Clea DuVall                        23.0
# ...                    ...                         ...
# 295976       Sonny Byrkett                        38.0
# 295977       Sonny Byrkett                        38.0
# 295978       Susan Byrkett                        34.0
# 295980  Dorothy Elias-Fahn                        22.0
# 295981       Jonathan Fahn                        27.0
#
#        Freebase_Char_Actor_Map_ID Freebase_Char_ID Freebase_Actor_ID  year  \
# 0                      /m/0bgchxw       /m/0bgcj3x        /m/03wcfv7  2001
# 1                       /m/0jys3m       /m/0bgchn4         /m/0346l4  2001
# 2                       /m/0jys3g       /m/0bgchn_        /m/01vw26l  2001
# 3                      /m/02vchl6       /m/0bgchnq         /m/034hyc  2001
# 4                      /m/02vbb3r       /m/0bgchp9         /m/01y9xg  2001
# ...                           ...              ...               ...   ...
# 295976                 /m/0kr405f       /m/0kr405k         /m/0gn4bz  1992
# 295977                 /m/0kr407w       /m/0kr407_         /m/0gn4bz  1992
# 295978                 /m/0kr40b9       /m/0kr40bf         /m/0gn4nd  1992
# 295980                 /m/0kr406c       /m/0kr406h         /m/0b_vcv  1992
# 295981                 /m/0kr405_       /m/0kr4090         /m/0bx7_j  1992
#
#         decade
# 0         2000
# 1         2000
# 2         2000
# 3         2000
# 4         2000
# ...        ...
# 295976    1990
# 295977    1990
# 295978    1990
# 295980    1990
# 295981    1990
#
# [189397 rows x 17 columns]

# %% [markdown]
# There are still some outliers as some movies include retrospectives on older movies with the same character (especially animation movies). This data is not representative for our analysis and will be filtered out as well. According to Roser et al. the life expectancy in the chosen countries was around 80 years in 2005. We will therefore set a threshold at 90 years to account for the increase in life expectancy with improved healthcare and some possible outliers.
#
# Source: https://ourworldindata.org/life-expectancy

# %%
# plot data to check for further inconsistencies
char_age.boxplot(by='Movie_Countries', column='Actor_Age_at_Movie_Release', rot=15)
# Out:
# <AxesSubplot: title={'center': 'Actor_Age_at_Movie_Release'}, xlabel='Movie_Countries'>

# %%
# filter out errors
char_age = char_age[char_age.Actor_Age_at_Movie_Release < 90]

# %% [markdown]
# For 25.7 % of the given actors we can analyze the age distribution:

# %%
nactors_age = aggregate.nactors(char_age)
print(f'- Number of actors:     {nactors_age} ({nactors_age / nactors_raw:.1%})')
# Out:
# - Number of actors:     34892 (25.7%)

# %% [markdown]
# In average over all the years from 1950 to 2013 the statistics in the Big 5 countries is very similar. Most of the actors were between 26 and 50 years old.

# %%
# compare countries' statistic
char_age.groupby('Movie_Countries').Actor_Age_at_Movie_Release.describe()
# Out:
#                              count       mean        std  min   25%   50%  \
# Movie_Countries
# France                      4864.0  40.847656  14.795182  4.0  30.0  39.0
# India                      31522.0  36.720989  13.295800  1.0  26.0  35.0
# Japan                       7961.0  37.127371  13.671876  1.0  27.0  35.0
# United Kingdom             17675.0  40.377595  13.910450  1.0  30.0  39.0
# United States of America  127262.0  39.379178  14.686246  1.0  29.0  38.0
#
#                            75%   max
# Movie_Countries
# France                    50.0  89.0
# India                     46.0  89.0
# Japan                     46.0  87.0
# United Kingdom            50.0  89.0
# United States of America  49.0  89.0

# %%
# plot new dataframe
char_age.boxplot(by='Movie_Countries', column='Actor_Age_at_Movie_Release', rot=15)
# Out:
# <AxesSubplot: title={'center': 'Actor_Age_at_Movie_Release'}, xlabel='Movie_Countries'>

# %% [markdown]
# Whereas in the 50's the USA, UK and France had a similar age of movie actors (~ 39 years), Japan and India had younger actors. With a rather strong decline in the 60's in France, France and Japan show a trend towards older actors in movies. In general the range of actors' ages is low in the USA and UK compared to the other three countries.

# %%
# compare over decades
# CI of 95 % was added
g = sns.lineplot(data=char_age, x="decade", y="Actor_Age_at_Movie_Release", hue="Movie_Countries", ci=95)
g.set(title='Age Distribution over the Decades')
# Out:
# C:\Users\Tim\AppData\Local\Temp\ipykernel_2704\211678920.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   g = sns.lineplot(data=char_age, x="decade", y="Actor_Age_at_Movie_Release", hue="Movie_Countries", ci=95)
# [Text(0.5, 1.0, 'Age Distribution over the Decades')]

# %% [markdown]
# #### 3.2.2 Gender

# %%
# assign to new variable
char_gender = characters

# %%
no_nan_gender = len(char_gender[char_gender.Actor_Gender.isna()])
print(f"There are {no_nan_gender} NaN values for the gender of actors.")
# Out:
# There are 20869 NaN values for the gender of actors.

# %%
# drop missing data
char_gender = char_gender.dropna(subset='Actor_Gender')

# %% [markdown]
# For 41.1 % of the given actors we can analyze the gender ratio:

# %%
nactors_gender = aggregate.nactors(char_gender)
print(f'- Number of actors:     {nactors_gender} ({nactors_gender / nactors_raw:.1%})')
# Out:
# - Number of actors:     55770 (41.1%)

# %% [markdown]
# In general the number of female actors in movies was much less than the number of male actors. Is the movie industry really male dominated or did it change over time?

# %%
# compare male and female in different countries
char_gender.groupby(['Actor_Gender', 'Movie_Countries'])['Actor_Gender'].count()
# Out:
# Actor_Gender  Movie_Countries
# F             France                       2391
#               India                       14411
#               Japan                        3385
#               United Kingdom               6254
#               United States of America    48165
# M             France                       3746
#               India                       27816
#               Japan                        5514
#               United Kingdom              13469
#               United States of America    98661
# Name: Actor_Gender, dtype: int64

# %%
# plot data
gender_plot = sns.countplot(data=char_gender, x='Movie_Countries', hue='Actor_Gender')
gender_plot.set_xticklabels(gender_plot.get_xticklabels(), rotation=15)
gender_plot.set(title='Gender distribution in the Big 5 Movie Industries')
# Out:
# [Text(0.5, 1.0, 'Gender distribution in the Big 5 Movie Industries')]

# %%
# split the data into two columns and creating indicator variables for Male and Female
char_gender = pd.get_dummies(char_gender, columns=['Actor_Gender'])
char_gender.head()
# Out:
#    index  Wikipedia_Movie_ID           Movie_Countries Freebase_Movie_ID  \
# 0      0              975900  United States of America         /m/03vyhn
# 1      1              975900  United States of America         /m/03vyhn
# 2      2              975900  United States of America         /m/03vyhn
# 3      3              975900  United States of America         /m/03vyhn
# 4      4              975900  United States of America         /m/03vyhn
#
#   Movie_Release_Date              Character_Name   Actor_DOB  Actor_Height  \
# 0         2001-08-24                    Akooshay  1958-08-26         1.620
# 1         2001-08-24  Lieutenant Melanie Ballard  1974-08-15         1.780
# 2         2001-08-24         Desolation Williams  1969-06-15         1.727
# 3         2001-08-24          Sgt Jericho Butler  1967-09-12         1.750
# 4         2001-08-24             Bashira Kincaid  1977-09-25         1.650
#
#   Actor_Ethnicity          Actor_Name  Actor_Age_at_Movie_Release  \
# 0             NaN      Wanda De Jesus                        42.0
# 1      /m/044038p  Natasha Henstridge                        27.0
# 2         /m/0x67            Ice Cube                        32.0
# 3             NaN       Jason Statham                        33.0
# 4             NaN         Clea DuVall                        23.0
#
#   Freebase_Char_Actor_Map_ID Freebase_Char_ID Freebase_Actor_ID  year  decade  \
# 0                 /m/0bgchxw       /m/0bgcj3x        /m/03wcfv7  2001    2000
# 1                  /m/0jys3m       /m/0bgchn4         /m/0346l4  2001    2000
# 2                  /m/0jys3g       /m/0bgchn_        /m/01vw26l  2001    2000
# 3                 /m/02vchl6       /m/0bgchnq         /m/034hyc  2001    2000
# 4                 /m/02vbb3r       /m/0bgchp9         /m/01y9xg  2001    2000
#
#    Actor_Gender_F  Actor_Gender_M
# 0               1               0
# 1               1               0
# 2               0               1
# 3               0               1
# 4               1               0

# %%
# calculate female/male ratio for decades
# create new dataframe
df_gender_ratio = load.gender_ratio(char_gender)

# %% [markdown]
# Except for India there is a trend towards more actresses in movies. Only India shows a trend towards more male actors. However, India had the highest ratio in the 50's. In none of the countries were as many male as female actors in 2013.

# %%
# plot new dataframe
g = sns.lineplot(data=df_gender_ratio, x='decade', y='Ratio F/M', hue='Movie_Countries')
g.set(title='Gender Ratio over Decades in different Countries')
# Out:
# [Text(0.5, 1.0, 'Gender Ratio over Decades in different Countries')]

# %% [markdown]
# We will now compare the age between male and female actors in the different countries.
# In average female actors are much younger (33.82 +/- 13.9) than male actors (41.55 +/- 13.94).

# %%
# use gender as additional information
# assign data to male/female
female_age, male_age = load.indicator_mf(char_age)

# %%
female_age.Actor_Age_at_Movie_Release.describe()
# Out:
# count    62511.000000
# mean        33.823807
# std         13.901891
# min          1.000000
# 25%         24.000000
# 50%         31.000000
# 75%         41.000000
# max         89.000000
# Name: Actor_Age_at_Movie_Release, dtype: float64

# %%
male_age.Actor_Age_at_Movie_Release.describe()
# Out:
# count    125823.000000
# mean         41.546490
# std          13.937652
# min           1.000000
# 25%          31.000000
# 50%          40.000000
# 75%          51.000000
# max          89.000000
# Name: Actor_Age_at_Movie_Release, dtype: float64

# %% [markdown]
# France has in average the oldest actresses whereas India has the youngest. The male actors are in every country around the same age.

# %%
aggregate.stats_age_by_country(female_age)
# Out:
#                             count       mean        std  min   25%   50%  \
# Movie_Countries
# France                     1890.0  36.614815  14.913436  5.0  26.0  33.0
# India                     11184.0  28.854793  11.361938  1.0  22.0  26.0
# Japan                      2969.0  31.818121  12.759857  1.0  23.0  29.0
# United Kingdom             5440.0  35.981066  14.458219  2.0  25.0  32.0
# United States of America  41028.0  34.908867  14.155075  1.0  25.0  32.0
#
#                            75%   max
# Movie_Countries
# France                    44.0  89.0
# India                     33.0  89.0
# Japan                     38.0  86.0
# United Kingdom            44.0  89.0
# United States of America  42.0  89.0

# %%
aggregate.stats_age_by_country(male_age)
# Out:
#                             count       mean        std  min   25%   50%  \
# Movie_Countries
# France                     2937.0  43.556691  14.037038  4.0  33.0  42.0
# India                     20291.0  41.051550  12.254879  1.0  32.0  40.0
# Japan                      4916.0  40.414565  13.168855  3.0  31.0  39.0
# United Kingdom            12141.0  42.328391  13.169950  1.0  33.0  41.0
# United States of America  85538.0  41.548949  14.436784  1.0  31.0  40.0
#
#                            75%   max
# Movie_Countries
# France                    53.0  89.0
# India                     49.0  89.0
# Japan                     49.0  87.0
# United Kingdom            51.0  89.0
# United States of America  51.0  89.0

# %%
# Age of women in movie industry in different countries
# CI of 95 % was added
g = sns.lineplot(data=female_age, x="decade", y="Actor_Age_at_Movie_Release", hue="Movie_Countries", ci=95)
g.set(title='Distribution of Age of Actresses over Decades')
# Out:
# C:\Users\Tim\AppData\Local\Temp\ipykernel_2704\2386693275.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   g = sns.lineplot(data=female_age, x="decade", y="Actor_Age_at_Movie_Release", hue="Movie_Countries", ci=95)
# [Text(0.5, 1.0, 'Distribution of Age of Actresses over Decades')]

# %%
# Age of men in movie industry in different countries
# CI of 95 % was added
g = sns.lineplot(data=male_age, x="decade", y="Actor_Age_at_Movie_Release", hue="Movie_Countries", ci=95)
g.set(title='Distribution of Age of Male Actors over Decades')
# Out:
# C:\Users\Tim\AppData\Local\Temp\ipykernel_2704\1495814536.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   g = sns.lineplot(data=male_age, x="decade", y="Actor_Age_at_Movie_Release", hue="Movie_Countries", ci=95)
# [Text(0.5, 1.0, 'Distribution of Age of Male Actors over Decades')]

# %% [markdown]
# #### 3.2.3 Ethnicity

# %%
# assign new variable
char_ethnicity = characters

# %%
no_nan_ethnicity = len(char_ethnicity[char_ethnicity.Actor_Ethnicity.isna()])
print(f"There are {no_nan_ethnicity} NaN values for the ethnicity of actors.")
# Out:
# There are 173240 NaN values for the ethnicity of actors.

# %%
# drop rows with missing values
char_ethnicity = char_ethnicity.dropna(subset='Actor_Ethnicity')

# %% [markdown]
# For 5 % of the given actors we can analyze the ethnicity:

# %%
nactors_ethn = aggregate.nactors(char_ethnicity)
print(f'- Number of actors:     {nactors_ethn} ({nactors_ethn / nactors_raw:.1%})')
# Out:
# - Number of actors:     6777 (5.0%)

# %% [markdown]
# Since there are so many different ethnicities but not much data about actors' ehtnicities, we try to measure the diversity by how many different ethnicities a country's movie industry has.
#
# Furtheremore, the ethnicity is encoded by Freebase IDs. We therefore use Wikidata Query Service (Wikipedia) to get all the Freebase IDs with the corresponding ethnicity. The Freebase IDs can then be assigned to ethnicity names.

# %% [markdown]
# The query given to the Wikidata Query Service was:

# %%
# SPARQL code to match wikidata
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX wikibase: <http://wikiba.se/ontology#>

SELECT DISTINCT ?item ?itemLabel ?freebaseID WHERE {
  # ?item p:P646 [ps:P646 ?freebaseID].
  VALUES ?freebaseID {query} # query contains all the freebase IDs
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}

# %%
# get the Freebase IDs and save them in a txt
FB_ID_TXT = '../data/fb_ids.txt'

with open(FB_ID_TXT, 'w') as f:
    for fb_id in char_ethnicity.Actor_Ethnicity.unique():
        f.write('"' + fb_id + '" ')

# %% [markdown]
# The output was downloaded as a JSON file and will be used for the assignments.

# %%
# load json file
FB_ETHNICITY_ASSIGNMENTS = '../data/query.json'

f = open(FB_ETHNICITY_ASSIGNMENTS)
freebase_ethnicity = json.load(f)
f.close()

# %%
# create mapping dictionary for Freebase to ethnicity name and replace value
char_ethnicity = clean.get_ethnicities(char_ethnicity, freebase_ethnicity)

# %% [markdown]
# There still exist Freebase IDs which couldn't be assigned as wikidata didn't find a corresponding name.

# %%
# get ids which couldn't be assigned
not_found_ethn = aggregate.not_assigned_fb_ids(char_ethnicity)        
print(f"There are {len(not_found_ethn)} IDs which couldn't be assigned.")
# Out:
# There are 41 IDs which couldn't be assigned.

# %%
unique_ethn = len(char_ethnicity.Actor_Ethnicity.unique())
print(f'There are {unique_ethn} different ethnicities in the dataset.')
# Out:
# There are 418 different ethnicities in the dataset.

# %%
# create dataframe containing the number of different ethnicities per country and decade
count_ethnic = aggregate.ethnicities_country(char_ethnicity)

# %% [markdown]
# The number of different ethnicities has risen over the decades. Since we only have data until 2013, the decade of 2010's is underpresented and therefore lower than the 2000's.

# %%
# plot number of ethnicities
count_ethnic.unstack().plot(kind='bar', title='Number of Different Ethnicities over Decades in the Big 5')
# Out:
# <AxesSubplot: title={'center': 'Number of Different Ethnicities over Decades in the Big 5'}, xlabel='Movie_Countries'>

# %% [markdown]
# As we have more data about the US they also have more different ethnicities in total. We will therefore get a ratio.

# %%
# ratio number of unique / number of actors
ratio_u_t = load.ethnicity_ratio(char_ethnicity)

# %%
ratio_u_t.unstack().plot(kind='bar', title='Ratio of Different Ethnicities Over Number of Actors in the Big 5')
# Out:
# <AxesSubplot: title={'center': 'Ratio of Different Ethnicities Over Number of Actors in the Big 5'}, xlabel='Movie_Countries'>

# %% [markdown]
# As in Asian countries the most representative ethnic group is supposedly Asians, we will examine the strongest ethnic groups in the countries.
#
# As can be seen, there are still some inconsistencies in the assignment of ethnicities. There are e.g. 'white people' but also nationalities given, like 'French' or 'Italians'. Or 'Japanese people' but also 'Asian people' which should be a more abstract expression containing all ethnicities from Asia. This has to be accounted for when working with ethnicities.

# %%
# get the top 5 ethnicities from each of the big 5 movie industries
top_ethn = load.top_n_ethnic(char_ethnicity, n=5)
top_ethn
# Out:
#                                             Count
# Movie_Countries          Actor_Ethnicity
# France                   French               534
#                          Jewish people         65
#                          white people          30
#                          Italians              27
#                          /m/02p656s            22
# India                    Indians            13822
#                          Tamil               1007
#                          Punjabis             939
#                          Malayali             884
#                          Marathi people       744
# Japan                    Japanese people      476
#                          Jewish people         19
#                          Asian people          18
#                          English people         9
#                          African Americans      8
# United Kingdom           English people      1592
#                          Jewish people        417
#                          British people       359
#                          Scottish people      262
#                          White British        242
# United States of America African Americans   7969
#                          Jewish people       6398
#                          Irish Americans     2638
#                          Italian Americans   2273
#                          white Americans     1700

# %%
# get the total number of actors with data about information grouped by country
total_number = char_ethnicity.groupby('Movie_Countries').Actor_Ethnicity\
.count().to_frame().rename(columns={'Actor_Ethnicity': 'Count'})

# %%
# percentage / ratio
top_perc = top_ethn.div(total_number).rename(columns={'Count': 'Fraction'})

# %%
# plot Distribution of Top 5 Ethnic Groups in the Big 5 Movie Industries
plot.ethnic_ratio_countries(top_perc)

# %% [markdown]
# #### 3.2.4 Height

# %%
# assign to new variable
char_height = characters

# %%
no_nan_height = len(char_height[char_height.Actor_Height.isna()])
print(f"There are {no_nan_height} NaN values for the height of actors.")
# Out:
# There are 143856 NaN values for the height of actors.

# %%
# drop rows with missing values
char_height = char_height.dropna(subset='Actor_Height')

# %% [markdown]
# The maximum height of 510 m is impossible, therefore, there exist inconsistent data about the actor's height. The tallest person was 2.72 m. Therefore, we will filter out every actor above that height.
#
# Source: https://en.wikipedia.org/wiki/Robert_Wadlow

# %%
# check statistics for inconsistencies
char_height.Actor_Height.describe()
# Out:
# count    100825.000000
# mean          1.769042
# std           2.885711
# min           0.813000
# 25%           1.680000
# 50%           1.750000
# 75%           1.830000
# max         510.000000
# Name: Actor_Height, dtype: float64

# %%
# filter data
char_height = char_height[char_height.Actor_Height < 2.72]

# %% [markdown]
# For 8.1 % of the given actors we can analyze the height:

# %%
nactors_height = aggregate.nactors(char_height)
print(f'- Number of actors:     {nactors_height} ({nactors_height / nactors_raw:.1%})')
# Out:
# - Number of actors:     10975 (8.1%)

# %%
# plot data
char_height.boxplot(by='Movie_Countries', column='Actor_Height', rot=15)
# Out:
# <AxesSubplot: title={'center': 'Actor_Height'}, xlabel='Movie_Countries'>

# %%
# check height over decades
# CI of 95 % was added
sns.lineplot(data=char_height, x="decade", y="Actor_Height", hue="Movie_Countries", ci=95)
# Out:
# C:\Users\Tim\AppData\Local\Temp\ipykernel_2704\1790738641.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.lineplot(data=char_height, x="decade", y="Actor_Height", hue="Movie_Countries", ci=95)
# <AxesSubplot: xlabel='decade', ylabel='Actor_Height'>

# %% [markdown]
# As women are generally less tall than men, we will split the data into male and female.

# %%
# use gender as additional information
# assign data to male/female
female_height, male_height = load.indicator_mf(char_height)

# %% [markdown]
# To check for discrimination we need to compare the smallest and tallest persons during the decades. The average value does not give much information about that.

# %%
female_height.Actor_Height.describe()
# Out:
# count    36376.000000
# mean         1.661554
# std          0.068711
# min          1.060000
# 25%          1.620000
# 50%          1.660000
# 75%          1.702000
# max          2.010000
# Name: Actor_Height, dtype: float64

# %%
male_height.Actor_Height.describe()
# Out:
# count    64349.000000
# mean         1.800644
# std          0.088822
# min          0.813000
# 25%          1.750000
# 50%          1.800000
# 75%          1.850000
# max          2.316480
# Name: Actor_Height, dtype: float64

# %%
# get the min and max values
min_max_mh = aggregate.max_min(male_height)
min_max_fh = aggregate.max_min(female_height)

# %% [markdown]
# The UK and the USA had both very tall and short male actors over the time of 1950-2013. France and India started including very short male actors from the 2000's. Tall people were always part of movies, however, short men were not included in Japan. Short-grown women were not part of movies until the 80's.

# %%
# check male height over decades
plot.height_decades(min_max_mh, 'Male')

# %%
# check female height over decades
plot.height_decades(min_max_fh, 'Female')

# %% [markdown]
# ### 3.3 Success across industries
#
# Our intial question, but now more precisely comparing across different countries.
# What factors predict the success of a movie (financial and rating), and do they differ across the different countries?

# %% [markdown]
# We are interested in collecting other metadata to support our analysis. For this we harverst the imdb rating and we use for that imdb python api that seem to be more native and easier than through requests as the html location differ. The initial steps for how to perform it with beautiful soup will be as well showcased.

# %%
# sample data where there is 10 movies for each country and decade
sample = movies.groupby(['Movie_Countries', 'decade']).apply(lambda x: x.sample(10))
#sample_movies = movies[['Movie_Name', 'Movie_Runtime', 'Movie_Countries', 'decade']].drop_duplicates().sample(100)

# %%
def get_rating(movie_name):
    """Get the rating of a movie from IMDB"""	
    # get the rating of a movie
    imdb_obj = imdb.IMDb()
    print(f"Searching for {movie_name}...")
    search = imdb_obj.search_movie(movie_name)  # search for the movie name in the imdb database 
    if len(search) == 0:
        print(f"Movie {movie_name} not found.")
        return None
    else:
        movie_id = search[0].getID()  # get the id of the first result
        imdb_url = 'http://www.imdb.com//title/tt'+ movie_id +'/' # create the url
        #response = requests.get(imdb_url) # get the response
        #soup = BeautifulSoup(response.text, "html.parser") # parse the response but it is easier to harvest the data using the api
        movie_meta = imdb_obj.get_movie(movie_id)
        if 'rating' in movie_meta.keys():
            rating = movie_meta['rating']
            print(f"Rating of {movie_name} is {rating}")
            return rating
        else:
            print(f"Rating of {movie_name} not found.")
            return None

# %%
# get the rating of the movies in the sample
sample['rating'] = sample.Movie_Name.apply(get_rating)
# Out:
# Searching for Two Men in Manhattan...
# Rating of Two Men in Manhattan is 6.6
# Searching for Night and Fog...
# Movie Night and Fog not found.
# Searching for Diary of a Country Priest...
# Rating of Diary of a Country Priest is 7.8
# Searching for Manèges...
# Rating of Manèges is 7.2
# Searching for Massacre in Lace...
# Movie Massacre in Lace not found.
# Searching for Casque d'or...
# Rating of Casque d'or is 7.6
# Searching for Afrique 50...
# Rating of Afrique 50 is 7.2
# Searching for Cyrano de Bergerac...
# Rating of Cyrano de Bergerac is 7.5
# Searching for La Ronde...
# Movie La Ronde not found.
# Searching for La Marie du port...
# Movie La Marie du port not found.
# Searching for The Smugglers...
# Rating of The Smugglers is 6.2
# Searching for Two or Three Things I Know About Her...
# Movie Two or Three Things I Know About Her not found.
# Searching for The Two of Us...
# Rating of The Two of Us is 6.5
# Searching for The Sleeping Car Murders...
# Movie The Sleeping Car Murders not found.
# Searching for La Jetée...
# Movie La Jetée not found.
# Searching for Je t'aime, je t'aime...
# Movie Je t'aime, je t'aime not found.
# Searching for Shoot the Piano Player...
# Rating of Shoot the Piano Player is 8.2
# Searching for Les Abysses...
# Movie Les Abysses not found.
# Searching for Shoot the Piano Player...
# Movie Shoot the Piano Player not found.
# Searching for Jules and Jim...
# Movie Jules and Jim not found.
# Searching for Figaro-ci, Figaro-là...
# Movie Figaro-ci, Figaro-là not found.
# Searching for Elsa Fraulein SS...
# Rating of Elsa Fraulein SS is 3.6
# Searching for Two English Girls...
# Rating of Two English Girls is 7.2
# Searching for Death of a Corrupt Man...
# Movie Death of a Corrupt Man not found.
# Searching for The Bronte Sisters...
# Rating of The Bronte Sisters is 6.5
# Searching for Bilitis...
# Movie Bilitis not found.
# Searching for One More Effort, Chinamen, if you want to be revolutionaries!...
# Movie One More Effort, Chinamen, if you want to be revolutionaries! not found.
# Searching for Just Before Nightfall...
# Rating of Just Before Nightfall is 7.2
# Searching for The Story of Adele H....
# Movie The Story of Adele H. not found.
# Searching for Maîtresse...
# Movie Maîtresse not found.
# Searching for Chicken with Vinegar...
# Movie Chicken with Vinegar not found.
# Searching for Vagabond...
# Movie Vagabond not found.
# Searching for La Femme de l'aviateur...
# Movie La Femme de l'aviateur not found.
# Searching for Pierre and Djemila...
# Movie Pierre and Djemila not found.
# Searching for Diva...
# Rating of Diva is 6.4
# Searching for Les Misérables...
# Movie Les Misérables not found.
# Searching for Démolition d'un mur...
# Movie Démolition d'un mur not found.
# Searching for Emmanuelle 4...
# Rating of Emmanuelle 4 is 3.3
# Searching for Trop belle pour toi...
# Rating of Trop belle pour toi is 6.7
# Searching for Vagabond...
# Movie Vagabond not found.
# Searching for Louis, the Child King...
# Rating of Louis, the Child King is 6.2
# Searching for Encore...
# Movie Encore not found.
# Searching for Cold Water...
# Rating of Cold Water is 7.0
# Searching for Gito l'ingrat...
# Movie Gito l'ingrat not found.
# Searching for Romance...
# Rating of Romance is 5.2
# Searching for Le Colonel Chabert...
# Movie Le Colonel Chabert not found.
# Searching for Victor...
# Movie Victor not found.
# Searching for Sitcom...
# Movie Sitcom not found.
# Searching for Beau fixe...
# Rating of Beau fixe is 6.4
# Searching for Indochine...
# Movie Indochine not found.
# Searching for Ils se marièrent et eurent beaucoup d'enfants...
# Rating of Ils se marièrent et eurent beaucoup d'enfants is 6.4
# Searching for Two in the Wave...
# Rating of Two in the Wave is 6.8
# Searching for Cold Showers...
# Rating of Cold Showers is 6.1
# Searching for A Matter of Taste...
# Rating of A Matter of Taste not found.
# Searching for If I Were a Rich Man...
# Movie If I Were a Rich Man not found.
# Searching for Grande École...
# Rating of Grande École is 5.7
# Searching for Shall We Kiss?...
# Movie Shall We Kiss? not found.
# Searching for Les Chevaliers du ciel...
# Movie Les Chevaliers du ciel not found.
# Searching for God Is Great and I'm Not...
# Movie God Is Great and I'm Not not found.
# Searching for Anatomy of Hell...
# Rating of Anatomy of Hell is 4.4
# Searching for Polaroid Song...
# Movie Polaroid Song not found.
# Searching for The Guidance of Reason...
# Movie The Guidance of Reason not found.
# Searching for Derrière les murs...
# Rating of Derrière les murs is 4.3
# Searching for Asterix & Obelix : God save Britannia...
# Rating of Asterix & Obelix : God save Britannia is 5.3
# Searching for Last Screening...
# Rating of Last Screening is 5.6
# Searching for My Little Princess...
# Movie My Little Princess not found.
# Searching for Arthur 3: The War of the Two Worlds...
# Movie Arthur 3: The War of the Two Worlds not found.
# Searching for Of Gods and Men...
# Rating of Of Gods and Men is 7.2
# Searching for House of Tolerance...
# Rating of House of Tolerance is 6.7
# Searching for Happy Few...
# Rating of Happy Few is 5.6
# Searching for Shyamchi Aai...
# Movie Shyamchi Aai not found.
# Searching for Babul...
# Rating of Babul is 5.7
# Searching for Devdas...
# Movie Devdas not found.
# Searching for Mayurpankh...
# Rating of Mayurpankh is 6.2
# Searching for Kanhaiya...
# Movie Kanhaiya not found.
# Searching for Vipra Narayana...
# Rating of Vipra Narayana is 8.2
# Searching for Ponvayal...
# Rating of Ponvayal not found.
# Searching for Munimji...
# Movie Munimji not found.
# Searching for Pakkinti Ammayi...
# Movie Pakkinti Ammayi not found.
# Searching for Paigham...
# Movie Paigham not found.
# Searching for Raat Aur Din...
# Movie Raat Aur Din not found.
# Searching for Bharya Bharthalu...
# Movie Bharya Bharthalu not found.
# Searching for Loha Singh...
# Rating of Loha Singh not found.
# Searching for Ganga Maiyya Tohe Piyari Chadhaibo...
# Rating of Ganga Maiyya Tohe Piyari Chadhaibo is 5.8
# Searching for Tere Ghar ke Saamne...
# Movie Tere Ghar ke Saamne not found.
# Searching for Chaudhvin Ka Chand...
# Rating of Chaudhvin Ka Chand is 6.9
# Searching for Muthalali...
# Movie Muthalali not found.
# Searching for Pooja...
# Rating of Pooja is 5.3
# Searching for Pandava Vanavasam...
# Rating of Pandava Vanavasam is 8.4
# Searching for Inapraavugal...
# Rating of Inapraavugal not found.
# Searching for Mr. Natwarlal...
# Movie Mr. Natwarlal not found.
# Searching for Amar Deep...
# Movie Amar Deep not found.
# Searching for Neem Annapurna...
# Rating of Neem Annapurna is 5.8
# Searching for Shatranj Ke Khilari...
# Movie Shatranj Ke Khilari not found.
# Searching for Adavi Ramudu...
# Movie Adavi Ramudu not found.
# Searching for The Golden Fortress...
# Movie The Golden Fortress not found.
# Searching for Khote Sikkay...
# Rating of Khote Sikkay is 6.2
# Searching for America Ammayi...
# Rating of America Ammayi is 8.5
# Searching for Sawan Ke Geet...
# Rating of Sawan Ke Geet is 4.4
# Searching for Maha Sati Savitri...
# Movie Maha Sati Savitri not found.
# Searching for Sreedharante Onnam Thirumurivu...
# Movie Sreedharante Onnam Thirumurivu not found.
# Searching for Dharam Aur Kanoon...
# Movie Dharam Aur Kanoon not found.
# Searching for Hathyar...
# Rating of Hathyar is 6.5
# Searching for Mahaguru...
# Rating of Mahaguru is 5.0
# Searching for Ponmuttayidunna Tharavu...
# Rating of Ponmuttayidunna Tharavu is 8.1
# Searching for Uttar Dakshin...
# Rating of Uttar Dakshin is 4.3
# Searching for Lootmaar...
# Rating of Lootmaar is 6.2
# Searching for Bandhana...
# Rating of Bandhana is 8.2
# Searching for Dharmam...
# Movie Dharmam not found.
# Searching for Zakhmi Sher...
# Movie Zakhmi Sher not found.
# Searching for Rang...
# Rating of Rang is 4.7
# Searching for Swaham...
# Rating of Swaham is 7.4
# Searching for Sallapam...
# Movie Sallapam not found.
# Searching for Border...
# Rating of Border is 7.0
# Searching for Deiva Vaakku...
# Movie Deiva Vaakku not found.
# Searching for Baazi...
# Movie Baazi not found.
# Searching for Nirnayam...
# Movie Nirnayam not found.
# Searching for Yamaleela...
# Movie Yamaleela not found.
# Searching for Pudhiya Mugam...
# Rating of Pudhiya Mugam is 6.3
# Searching for 1942: A Love Story...
# Rating of 1942: A Love Story is 7.2
# Searching for Accident...
# Rating of Accident is 3.3
# Searching for Cover Story...
# Rating of Cover Story is 3.9
# Searching for Aakheer...
# Rating of Aakheer is 4.6
# Searching for Gandhi, My Father...
# Rating of Gandhi, My Father is 7.3
# Searching for Hey Ram...
# Rating of Hey Ram is 7.9
# Searching for Kyaa Kool Hai Hum...
# Movie Kyaa Kool Hai Hum not found.
# Searching for Welcome...
# Movie Welcome not found.
# Searching for Yeh Dil Aashiqanaa...
# Rating of Yeh Dil Aashiqanaa is 4.3
# Searching for Adhinayak...
# Rating of Adhinayak not found.
# Searching for Perazhagan...
# Movie Perazhagan not found.
# Searching for Delhi Belly...
# Rating of Delhi Belly is 7.5
# Searching for Once Upon A Time In Mumbai...
# Movie Once Upon A Time In Mumbai not found.
# Searching for Pyaar Impossible...
# Movie Pyaar Impossible not found.
# Searching for Once Upon a Warrior...
# Rating of Once Upon a Warrior is 5.3
# Searching for Tees Mar Khan...
# Rating of Tees Mar Khan not found.
# Searching for Makeup Man...
# Rating of Makeup Man is 5.3
# Searching for Rana...
# Rating of Rana is 6.2
# Searching for Run Bhola Run...
# Rating of Run Bhola Run is 6.0
# Searching for The Temple...
# Rating of The Temple is 8.2
# Searching for Dark Rainbow...
# Rating of Dark Rainbow not found.
# Searching for Jazz musume tanjō...
# Rating of Jazz musume tanjō is 5.8
# Searching for Godzilla Raids Again...
# Movie Godzilla Raids Again not found.
# Searching for The H-Man...
# Movie The H-Man not found.
# Searching for Jun'ai monogatari...
# Rating of Jun'ai monogatari is 7.4
# Searching for Giants and Toys...
# Rating of Giants and Toys is 7.3
# Searching for The Temptress and the Monk...
# Movie The Temptress and the Monk not found.
# Searching for The Mysterians...
# Movie The Mysterians not found.
# Searching for Sakon torimonochō: senketsu no tegata...
# Movie Sakon torimonochō: senketsu no tegata not found.
# Searching for Jazz musume tanjō...
# Rating of Jazz musume tanjō is 5.8
# Searching for The Mysterians...
# Movie The Mysterians not found.
# Searching for King Kong vs. Godzilla...
# Movie King Kong vs. Godzilla not found.
# Searching for Samurai Banners...
# Rating of Samurai Banners is 7.1
# Searching for Tora-San's Cherished Mother...
# Rating of Tora-San's Cherished Mother is 7.1
# Searching for The Insect Woman...
# Movie The Insect Woman not found.
# Searching for Yojimbo...
# Movie Yojimbo not found.
# Searching for High and Low...
# Movie High and Low not found.
# Searching for All Monsters Attack...
# Movie All Monsters Attack not found.
# Searching for Tattooed Life...
# Movie Tattooed Life not found.
# Searching for The Pornographers...
# Rating of The Pornographers is 7.2
# Searching for Twin Sisters of Kyoto...
# Movie Twin Sisters of Kyoto not found.
# Searching for Double Suicide of Sonezaki...
# Rating of Double Suicide of Sonezaki is 6.7
# Searching for Female Convict Scorpion: Grudge Song...
# Movie Female Convict Scorpion: Grudge Song not found.
# Searching for Lone Wolf and Cub: Baby Cart in Peril...
# Movie Lone Wolf and Cub: Baby Cart in Peril not found.
# Searching for Woman on the Night Train...
# Rating of Woman on the Night Train is 5.6
# Searching for Stray Cat Rock: Sex Hunter...
# Movie Stray Cat Rock: Sex Hunter not found.
# Searching for Tabi no omosa...
# Rating of Tabi no omosa is 6.8
# Searching for Return of The Street Fighter...
# Rating of Return of The Street Fighter is 6.3
# Searching for Woman with Red Hair...
# Rating of Woman with Red Hair is 5.7
# Searching for Tattooed Flower Vase...
# Movie Tattooed Flower Vase not found.
# Searching for Street Mobster...
# Rating of Street Mobster is 7.1
# Searching for Burst City...
# Movie Burst City not found.
# Searching for Typhoon Club...
# Rating of Typhoon Club is 7.0
# Searching for Once Upon a Time...
# Movie Once Upon a Time not found.
# Searching for Godzilla vs. Biollante...
# Movie Godzilla vs. Biollante not found.
# Searching for The Legend of Shenlong: Curse of the Blood Rubies...
# Movie The Legend of Shenlong: Curse of the Blood Rubies not found.
# Searching for Eijanaika...
# Movie Eijanaika not found.
# Searching for Amon Saga...
# Rating of Amon Saga is 5.6
# Searching for Leda: The Fantastic Adventure Of Yohko...
# Movie Leda: The Fantastic Adventure Of Yohko not found.
# Searching for Abnormal Excitement: Nao Saejima...
# Movie Abnormal Excitement: Nao Saejima not found.
# Searching for Zigeunerweisen...
# Movie Zigeunerweisen not found.
# Searching for Mikadroid: Robokill Beneath Discoclub Layla...
# Rating of Mikadroid: Robokill Beneath Discoclub Layla is 5.6
# Searching for The Super Dimension Fortress Macross II: Lovers, Again...
# Movie The Super Dimension Fortress Macross II: Lovers, Again not found.
# Searching for Wkw/tk/1996@7'55"hk.net...
# Movie Wkw/tk/1996@7'55"hk.net not found.
# Searching for A Lonesome, Final Battle: The Father of Z-Warrior Son Gokū, who Challenged Freeza...
# Rating of A Lonesome, Final Battle: The Father of Z-Warrior Son Gokū, who Challenged Freeza is 7.8
# Searching for Crayon Shin-chan: The Secret Treasure of Buri Buri Kingdom...
# Rating of Crayon Shin-chan: The Secret Treasure of Buri Buri Kingdom is 6.5
# Searching for Dragon Ball Z: Broly – The Legendary Super Saiyan...
# Rating of Dragon Ball Z: Broly – The Legendary Super Saiyan is 7.4
# Searching for Tokyo Decadence...
# Movie Tokyo Decadence not found.
# Searching for Lupin the Third: The Movie - Lupin vs. the Clones...
# Movie Lupin the Third: The Movie - Lupin vs. the Clones not found.
# Searching for All Purpose Cultural Cat-Girl Nuku Nuku DASH!...
# Rating of All Purpose Cultural Cat-Girl Nuku Nuku DASH! is 7.6
# Searching for A Scene at the Sea...
# Movie A Scene at the Sea not found.
# Searching for Molester's Bus 2: Heat of the Over Thirty...
# Movie Molester's Bus 2: Heat of the Over Thirty not found.
# Searching for Gun Crazy: A Woman From Nowhere...
# Movie Gun Crazy: A Woman From Nowhere not found.
# Searching for Ashurajou no Hitomi...
# Movie Ashurajou no Hitomi not found.
# Searching for Memoirs of a Teenage Amnesiac...
# Movie Memoirs of a Teenage Amnesiac not found.
# Searching for Death Trance...
# Movie Death Trance not found.
# Searching for The Cat Returns...
# Movie The Cat Returns not found.
# Searching for Hoshizora Kiseki...
# Rating of Hoshizora Kiseki is 5.1
# Searching for Professor Layton and the Eternal Diva...
# Movie Professor Layton and the Eternal Diva not found.
# Searching for School Days with a Pig...
# Movie School Days with a Pig not found.
# Searching for Battle Royale...
# Movie Battle Royale not found.
# Searching for The Drudgery Train...
# Rating of The Drudgery Train is 6.8
# Searching for Shirome...
# Movie Shirome not found.
# Searching for Key of Life...
# Rating of Key of Life is 6.9
# Searching for Mutant Girls Squad...
# Rating of Mutant Girls Squad is 5.6
# Searching for Horny House of Horror...
# Rating of Horny House of Horror is 4.3
# Searching for The Woodsman and the Rain...
# Movie The Woodsman and the Rain not found.
# Searching for Legend of the Millennium Dragon...
# Rating of Legend of the Millennium Dragon is 5.6
# Searching for Dragon Ball: Episode of Bardock...
# Rating of Dragon Ball: Episode of Bardock is 7.3
# Searching for Tokumei Sentai Go-Busters the Movie: Protect the Tokyo Enetower!...
# Movie Tokumei Sentai Go-Busters the Movie: Protect the Tokyo Enetower! not found.
# Searching for Outrage...
# Movie Outrage not found.
# Searching for Dangerous Exile...
# Movie Dangerous Exile not found.
# Searching for Heart of a Child...
# Rating of Heart of a Child is 6.8
# Searching for On Such a Night...
# Rating of On Such a Night is 7.0
# Searching for Operation Amsterdam...
# Movie Operation Amsterdam not found.
# Searching for South of Algiers...
# Movie South of Algiers not found.
# Searching for The Man Between...
# Rating of The Man Between is 7.0
# Searching for The Last Man to Hang?...
# Rating of The Last Man to Hang? is 5.9
# Searching for The Belles of St Trinian's...
# Movie The Belles of St Trinian's not found.
# Searching for Lock Up Your Daughters...
# Rating of Lock Up Your Daughters not found.
# Searching for Shadow of a Man...
# Movie Shadow of a Man not found.
# Searching for The Deadly Bees...
# Rating of The Deadly Bees is 4.1
# Searching for The Devil Rides Out...
# Movie The Devil Rides Out not found.
# Searching for The Nine Ages of Nakedness...
# Rating of The Nine Ages of Nakedness is 4.6
# Searching for The Day the Earth Caught Fire...
# Rating of The Day the Earth Caught Fire is 7.2
# Searching for Far from the Madding Crowd...
# Rating of Far from the Madding Crowd is 7.1
# Searching for Bunny Lake Is Missing...
# Movie Bunny Lake Is Missing not found.
# Searching for Oscar Wilde...
# Movie Oscar Wilde not found.
# Searching for 80,000 Suspects...
# Rating of 80,000 Suspects is 5.9
# Searching for Solo for Sparrow...
# Rating of Solo for Sparrow is 6.4
# Searching for Gorgo...
# Movie Gorgo not found.
# Searching for Lisztomania...
# Rating of Lisztomania is 6.1
# Searching for Licensed to Love and Kill...
# Rating of Licensed to Love and Kill is 4.3
# Searching for Tiffany Jones...
# Rating of Tiffany Jones is 4.7
# Searching for Carry On at Your Convenience...
# Rating of Carry On at Your Convenience is 6.2
# Searching for Frankenstein and the Monster from Hell...
# Movie Frankenstein and the Monster from Hell not found.
# Searching for Performance...
# Rating of Performance is 6.8
# Searching for Life of Brian...
# Rating of Life of Brian is 8.0
# Searching for Pope Joan...
# Rating of Pope Joan is 6.7
# Searching for Zardoz...
# Rating of Zardoz is 5.8
# Searching for The End of the Road...
# Movie The End of the Road not found.
# Searching for Salome's Last Dance...
# Movie Salome's Last Dance not found.
# Searching for The Living Daylights...
# Rating of The Living Daylights is 6.7
# Searching for Bellman and True...
# Movie Bellman and True not found.
# Searching for A Grand Day Out...
# Rating of A Grand Day Out is 7.7
# Searching for Twelfth Night...
# Movie Twelfth Night not found.
# Searching for Time Bandits...
# Rating of Time Bandits is 6.9
# Searching for Wish You Were Here...
# Rating of Wish You Were Here is 5.9
# Searching for Time Bandits...
# Rating of Time Bandits is 6.9
# Searching for The Kitchen Toto...
# Movie The Kitchen Toto not found.
# Searching for The Secret Policeman's Other Ball...
# Movie The Secret Policeman's Other Ball not found.
# Searching for The Krays...
# Movie The Krays not found.
# Searching for Hilary and Jackie...
# Rating of Hilary and Jackie is 7.3
# Searching for Bitter Moon...
# Rating of Bitter Moon is 7.2
# Searching for Sharpe's Siege...
# Rating of Sharpe's Siege is 7.9
# Searching for Ashes to Ashes...
# Movie Ashes to Ashes not found.
# Searching for Pib and Pog...
# Movie Pib and Pog not found.
# Searching for Beautiful People...
# Rating of Beautiful People is 4.7
# Searching for Like It Is...
# Rating of Like It Is is 6.4
# Searching for Stiff Upper Lips...
# Rating of Stiff Upper Lips is 6.2
# Searching for Ashes to Ashes...
# Rating of Ashes to Ashes is 4.5
# Searching for The English Surgeon...
# Rating of The English Surgeon is 8.1
# Searching for 24 Hour Party People...
# Rating of 24 Hour Party People is 7.3
# Searching for Room to Let...
# Movie Room to Let not found.
# Searching for God on Trial...
# Movie God on Trial not found.
# Searching for American Cousins...
# Movie American Cousins not found.
# Searching for A Massacre Foretold...
# Rating of A Massacre Foretold is 7.5
# Searching for Cashback...
# Movie Cashback not found.
# Searching for The Age of Stupid...
# Rating of The Age of Stupid is 7.0
# Searching for Doghouse...
# Movie Doghouse not found.
# Searching for Life and Lyrics...
# Rating of Life and Lyrics is 5.3
# Searching for Made in Dagenham...
# Rating of Made in Dagenham is 7.1
# Searching for The Heavy...
# Rating of The Heavy is 4.9
# Searching for The Awakening...
# Rating of The Awakening is 6.4
# Searching for Re-Uniting the Rubins...
# Movie Re-Uniting the Rubins not found.
# Searching for The First Men in the Moon...
# Rating of The First Men in the Moon is 6.1
# Searching for United...
# Rating of United is 7.3
# Searching for 51 Degrees...
# Movie 51 Degrees not found.
# Searching for A Lonely Place to Die...
# Movie A Lonely Place to Die not found.
# Searching for Jackboots on Whitehall...
# Movie Jackboots on Whitehall not found.
# Searching for Life Just Is...
# Movie Life Just Is not found.
# Searching for The Phenix City Story...
# Movie The Phenix City Story not found.
# Searching for Cheaper by the Dozen...
# Movie Cheaper by the Dozen not found.
# Searching for Girls in the Night...
# Rating of Girls in the Night is 7.0
# Searching for The Searchers...
# Rating of The Searchers is 7.9
# Searching for A Girl in Every Port...
# Rating of A Girl in Every Port is 5.5
# Searching for Yellowstone Kelly...
# Rating of Yellowstone Kelly is 6.5
# Searching for Twilight for the Gods...
# Rating of Twilight for the Gods is 5.8
# Searching for The Blob...
# Movie The Blob not found.
# Searching for Scandal at Scourie...
# Rating of Scandal at Scourie is 6.6
# Searching for Listen, Judge...
# Rating of Listen, Judge is 7.3
# Searching for A New Kind of Love...
# Movie A New Kind of Love not found.
# Searching for The Magnificent Seven...
# Rating of The Magnificent Seven is 8.6
# Searching for The Wizard of Mars...
# Movie The Wizard of Mars not found.
# Searching for The T.A.M.I. Show...
# Rating of The T.A.M.I. Show is 8.2
# Searching for Shenandoah...
# Rating of Shenandoah is 7.3
# Searching for The Agony and the Ecstasy...
# Movie The Agony and the Ecstasy not found.
# Searching for We Shall Return...
# Rating of We Shall Return is 5.3
# Searching for The Music Man...
# Movie The Music Man not found.
# Searching for Sergeants Three...
# Movie Sergeants Three not found.
# Searching for Daddy's Gone A-Hunting...
# Rating of Daddy's Gone A-Hunting is 6.3
# Searching for Damnation Alley...
# Rating of Damnation Alley is 5.2
# Searching for Yuma...
# Movie Yuma not found.
# Searching for Darling Lili...
# Rating of Darling Lili is 6.1
# Searching for The Strawberry Statement...
# Movie The Strawberry Statement not found.
# Searching for Smile...
# Movie Smile not found.
# Searching for Young Frankenstein...
# Rating of Young Frankenstein is 8.0
# Searching for Viva Knievel!...
# Movie Viva Knievel! not found.
# Searching for Halloween Is Grinch Night...
# Movie Halloween Is Grinch Night not found.
# Searching for Who'll Stop the Rain...
# Rating of Who'll Stop the Rain is 6.7
# Searching for Peopletoys...
# Rating of Peopletoys is 5.0
# Searching for The Beniker Gang...
# Movie The Beniker Gang not found.
# Searching for They Live...
# Rating of They Live is 7.2
# Searching for Amadeus...
# Rating of Amadeus is 8.4
# Searching for Date with an Angel...
# Movie Date with an Angel not found.
# Searching for Beirut: The Last Home Movie...
# Rating of Beirut: The Last Home Movie is 6.7
# Searching for Miss Firecracker...
# Movie Miss Firecracker not found.
# Searching for When Nature Calls...
# Movie When Nature Calls not found.
# Searching for Maria’s Lovers...
# Rating of Maria’s Lovers is 6.6
# Searching for Haunted Honeymoon...
# Movie Haunted Honeymoon not found.
# Searching for Hell Squad...
# Movie Hell Squad not found.
# Searching for Bad Girls...
# Movie Bad Girls not found.
# Searching for Wyatt Earp...
# Rating of Wyatt Earp is 6.7
# Searching for Bill & Ted's Bogus Journey...
# Rating of Bill & Ted's Bogus Journey is 6.3
# Searching for The Vagrant...
# Movie The Vagrant not found.
# Searching for When a Man Loves a Woman...
# Rating of When a Man Loves a Woman is 6.5
# Searching for Max, 13...
# Movie Max, 13 not found.
# Searching for Stupid Little Golf Video...
# Movie Stupid Little Golf Video not found.
# Searching for Ironclads...
# Rating of Ironclads is 6.1
# Searching for Switchback...
# Rating of Switchback is 6.4
# Searching for Surrender Dorothy...
# Movie Surrender Dorothy not found.
# Searching for Fat Albert...
# Rating of Fat Albert is 4.3
# Searching for My Best Friend's Girl...
# Rating of My Best Friend's Girl is 5.8
# Searching for Novocaine...
# Movie Novocaine not found.
# Searching for Soulkeeper...
# Rating of Soulkeeper is 4.9
# Searching for House of 1000 Corpses...
# Rating of House of 1000 Corpses is 6.0
# Searching for The Dhamma Brothers...
# Rating of The Dhamma Brothers is 7.6
# Searching for Claire...
# Rating of Claire not found.
# Searching for The Guitar...
# Movie The Guitar not found.
# Searching for Judas...
# Rating of Judas is 7.4
# Searching for Love's Enduring Promise...
# Rating of Love's Enduring Promise is 7.0
# Searching for Percy Jackson & the Olympians: Sea of Monsters...
# Rating of Percy Jackson & the Olympians: Sea of Monsters is 5.7
# Searching for Blood Into Wine...
# Rating of Blood Into Wine is 7.1
# Searching for Drive...
# Rating of Drive is 7.8
# Searching for Fireflies in the Garden...
# Movie Fireflies in the Garden not found.
# Searching for Stonehenge Apocalypse...
# Movie Stonehenge Apocalypse not found.
# Searching for Jeff...
# Movie Jeff not found.
# Searching for The Arc of Life...
# Rating of The Arc of Life is 7.0
# Searching for Conviction...
# Movie Conviction not found.
# Searching for The Amazing Spider-Man...
# Rating of The Amazing Spider-Man is 7.4
# Searching for The Bitter Pill...
# Movie The Bitter Pill not found.

# %%
sample.head(10)
# Out:
#                                index  Wikipedia_Movie_ID Freebase_Movie_ID  \
# Movie_Countries decade
# France          1950   62702   28136            20789377        /m/057ch2s
#                        125394  56424            20181860         /m/017js3
#                        138110  62020            29831417         /m/086pyj
#                        78613   35415            28126186        /m/0cm9vqf
#                        155544  69735            29002980        /m/0dgq9xq
#                        6567     2986             3654133         /m/09sg_s
#                        5336     2435            35002603        /m/0j62n_g
#                        153357  68788             4432750         /m/0c22kf
#                        176492  78978             1923722         /m/066fb9
#                        129379  58156            25289332        /m/09gcybf
#
#                                               Movie_Name Movie_Release_Date  \
# Movie_Countries decade
# France          1950   62702        Two Men in Manhattan         1959-10-16
#                        125394              Night and Fog         1955-01-01
#                        138110  Diary of a Country Priest         1951-01-01
#                        78613                     Manèges         1950-01-25
#                        155544           Massacre in Lace         1952-03-12
#                        6567                  Casque d'or         1952-04-16
#                        5336                   Afrique 50         1950-01-01
#                        153357         Cyrano de Bergerac         1950-01-01
#                        176492                   La Ronde         1950-01-01
#                        129379           La Marie du port         1950-02-25
#
#                                  Revenue  Movie_Runtime   Movie_Languages  \
# Movie_Countries decade
# France          1950   62702         NaN           84.0   French Language
#                        125394        NaN           32.0   French Language
#                        138110        NaN          115.0   French Language
#                        78613         NaN           91.0   French Language
#                        155544        NaN           97.0   French Language
#                        6567          NaN           94.0   French Language
#                        5336          NaN           17.0   French Language
#                        153357  1900000.0          112.0  English Language
#                        176492        NaN           93.0   French Language
#                        129379        NaN          100.0   French Language
#
#                               Movie_Countries    Movie_Genres  year  decade  \
# Movie_Countries decade
# France          1950   62702           France        Thriller  1959    1950
#                        125394          France      Short Film  1955    1950
#                        138110          France         Mystery  1951    1950
#                        78613           France       Melodrama  1950    1950
#                        155544          France   Crime Fiction  1952    1950
#                        6567            France           Drama  1952    1950
#                        5336            France      Short Film  1950    1950
#                        153357          France           Drama  1950    1950
#                        176492          France  Romantic drama  1950    1950
#                        129379          France    Romance Film  1950    1950
#
#                                rating
# Movie_Countries decade
# France          1950   62702      6.6
#                        125394     NaN
#                        138110     7.8
#                        78613      7.2
#                        155544     NaN
#                        6567       7.6
#                        5336       7.2
#                        153357     7.5
#                        176492     NaN
#                        129379     NaN

# %%
# drop rows with missing values
sample = sample.dropna(subset=['rating'])

# %%
sample.describe()
# Out:
#               index  Wikipedia_Movie_ID       Revenue  Movie_Runtime  \
# count    170.000000        1.700000e+02  2.200000e+01     146.000000
# mean   45324.311765        1.574861e+07  6.785821e+07     107.691781
# std    24391.698488        1.154283e+07  1.585666e+08      37.721039
# min      390.000000        1.792000e+04  1.900000e+06      17.000000
# 25%    24072.000000        4.575240e+06  7.319495e+06      90.000000
# 50%    51617.500000        1.486190e+07  2.254856e+07     102.000000
# 75%    65159.750000        2.625152e+07  4.700489e+07     122.000000
# max    81306.000000        3.669992e+07  7.522166e+08     360.000000
#
#               year       decade      rating
# count   170.000000   170.000000  170.000000
# mean   1985.129412  1981.000000    6.410588
# std      19.776436    20.341755    1.133359
# min    1950.000000  1950.000000    3.300000
# 25%    1969.000000  1960.000000    5.700000
# 50%    1987.000000  1980.000000    6.500000
# 75%    2004.000000  2000.000000    7.200000
# max    2013.000000  2010.000000    8.600000

# %%
sample.rating.hist()
# Out:
# <AxesSubplot: >

# %%
# plot data for specific countries
sns.boxplot(data=sample, x="Movie_Countries", y="rating", hue="decade")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# plot rating over decades
sns.lineplot(data=sample, x="decade", y="rating", hue="Movie_Countries")
# Out:
# <AxesSubplot: xlabel='decade', ylabel='rating'>

# %% [markdown]
# ## References
#
# [1] “Global Box Office Down 72%, Digital Leads Home Entertainment in 2020,” Boxoffice, Mar. 26, 2021. https://www.boxofficepro.com/global-box-office-down-72-digital-leads-home-entertainment-in-2020/ (accessed Nov. 16, 2022).
